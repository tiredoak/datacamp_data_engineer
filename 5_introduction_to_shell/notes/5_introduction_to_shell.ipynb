# %% [markdown]
# # Manipulating Files and Directories

# %% [markdown]
# We use graphical displays to interact with computers (GUIs) but a lot of repetitive tasks could be achieved faster if we use the command line.

# %%
# to see where we are in the filesystem
# !pwd
# Out:
# /Users/miguel.carvalho/dev/datacamp/5_introduction_to_shell/notes

# %% [markdown]
# ## Quick intro
#
# - Paths starting with `/` are absolute and paths not starting with `/` are relative
# - `~`refers to home directory
# - some basic commands
#     - `cd`: `c`hange `d`irectory
#     - `ls`: `l`i`s`t files
#     - `mv`: `m`o`v`e file (also renames)
#     - `mkdir`: `m`a`k`e `dir`ectory
#     - `rmdir`: `r`e`m`ove `dir`ectory (only if empty)
#     - `cat`: con`cat`enate a file (used to just view its contents)

# %% [markdown]
# ## `less`
#
# `less` can be used to view the contents of files, one page at a time. After, we can use the spacebar to see the next chunk, `:n` to see the next file, and `:q` to quit.

# %%
# !ls
# Out:
# 5_introduction_to_shell.ipynb

# %%
# !less 5_introduction_to_shell.ipynb
# Out:
# {7=
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# Manipulating Files and Directories"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "We use graphical displays to interact with computers (GUIs) but a lot of repetitive tasks could be achieved faster if we use the command line."
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 3,
#    "metadata": {},
#    "outputs": [
#     {
#      "name": "stdout",ll.ipynb
# :

# %% [markdown]
# ## `head`
#
# `head` displays the first lines of a given file.

# %%
# !head 5_introduction_to_shell.ipynb
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# Manipulating Files and Directories"
#    ]
#   },
#   {

# %% [markdown]
# ## Flags
#
# Flags can be used to give more granular control to commands. They usually consist of `-` and a single letter indicating the flag's functionality (e.g. `-n` usually means new lines).
#
# - Flags should come before filenames
# - Adding a space after the flag is good style

# %%
# !head -n 20 5_introduction_to_shell.ipynb
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# Manipulating Files and Directories"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "We use graphical displays to interact with computers (GUIs) but a lot of repetitive tasks could be achieved faster if we use the command line."
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 3,
#    "metadata": {},

# %% [markdown]
# ## Listing everything under a directory
#
# We can use the flag `-R` (recursive) to print everything under a directory. We can also use `-F` which makes the output more readable by adding `/` after directories and `*` after runnable programs.

# %%
# !ls -R -F ~/dev
# Out:
# core/     datacamp/ stuff/
#
# /Users/miguel.carvalho/dev/core:
# README.md  packages/  scripts/   venv/
#
# /Users/miguel.carvalho/dev/core/packages:
# __init__.py  build/       dist/        mk/          mk.egg-info/ setup.py
#
# /Users/miguel.carvalho/dev/core/packages/build:
# bdist.macosx-10.14-x86_64/ lib/
#
# /Users/miguel.carvalho/dev/core/packages/build/bdist.macosx-10.14-x86_64:
#
# /Users/miguel.carvalho/dev/core/packages/build/lib:
# mk/
#
# /Users/miguel.carvalho/dev/core/packages/build/lib/mk:
# __init__.py  bquery/      crawl/       nlp/         process/
# app_radar/   constants/   gcp/         plots/       tools/
#
# /Users/miguel.carvalho/dev/core/packages/build/lib/mk/app_radar:
# __init__.py
#
# /Users/miguel.carvalho/dev/core/packages/build/lib/mk/bquery:
# __init__.py
#
# /Users/miguel.carvalho/dev/core/packages/build/lib/mk/constants:
# __init__.py
#
# /Users/miguel.carvalho/dev/core/packages/build/lib/mk/crawl:
# __init__.py
#
# /Users/miguel.carvalho/dev/core/packages/build/lib/mk/gcp:
# __init__.py
#
# /Users/miguel.carvalho/dev/core/packages/build/lib/mk/nlp:
# __init__.py
#
# /Users/miguel.carvalho/dev/core/packages/build/lib/mk/plots:
# __init__.py
#
# /Users/miguel.carvalho/dev/core/packages/build/lib/mk/process:
# __init__.py
#
# /Users/miguel.carvalho/dev/core/packages/build/lib/mk/tools:
# __init__.py
#
# /Users/miguel.carvalho/dev/core/packages/dist:
# mk-2.0-py3.7.egg
#
# /Users/miguel.carvalho/dev/core/packages/mk:
# __init__.py  bquery/      crawl/       nlp/         process/
# app_radar/   constants/   gcp/         plots/       tools/
#
# /Users/miguel.carvalho/dev/core/packages/mk/app_radar:
# __init__.py
#
# /Users/miguel.carvalho/dev/core/packages/mk/bquery:
# __init__.py
#
# /Users/miguel.carvalho/dev/core/packages/mk/constants:
# __init__.py
#
# /Users/miguel.carvalho/dev/core/packages/mk/crawl:
# __init__.py
#
# /Users/miguel.carvalho/dev/core/packages/mk/gcp:
# __init__.py
#
# /Users/miguel.carvalho/dev/core/packages/mk/nlp:
# __init__.py
#
# /Users/miguel.carvalho/dev/core/packages/mk/plots:
# __init__.py
#
# /Users/miguel.carvalho/dev/core/packages/mk/process:
# __init__.py
#
# /Users/miguel.carvalho/dev/core/packages/mk/tools:
# __init__.py
#
# /Users/miguel.carvalho/dev/core/packages/mk.egg-info:
# PKG-INFO              dependency_links.txt
# SOURCES.txt           top_level.txt
#
# /Users/miguel.carvalho/dev/core/scripts:
# scrapers/
#
# /Users/miguel.carvalho/dev/core/scripts/scrapers:
# app_store_connect.py
#
# /Users/miguel.carvalho/dev/core/venv:
# installer.sh*        requirements_v1.txt*
#
# /Users/miguel.carvalho/dev/datacamp:
# 12_introduction_to_pyspark/
# 1_introduction_to_data_engineering/
# 1_introduction_to_data_engineering-1_introduction_to_data_engineering.ipynb
# 2_streamlined_data_ingestion_with_pandas/
# 3_software_engineering_for_data_scientists_in_python/
# 5_introduction_to_shell/
# README.md
#
# /Users/miguel.carvalho/dev/datacamp/12_introduction_to_pyspark:
# datasets/ notes/    slides/
#
# /Users/miguel.carvalho/dev/datacamp/12_introduction_to_pyspark/datasets:
# airports.csv  flights.csv   planes.csv
#
# /Users/miguel.carvalho/dev/datacamp/12_introduction_to_pyspark/notes:
# 11_introduction_to_pyspark.ipynb  spark-warehouse/
#
# /Users/miguel.carvalho/dev/datacamp/12_introduction_to_pyspark/notes/spark-warehouse:
#
# /Users/miguel.carvalho/dev/datacamp/12_introduction_to_pyspark/slides:
#
# /Users/miguel.carvalho/dev/datacamp/1_introduction_to_data_engineering:
# datasets/ notes/    slides/
#
# /Users/miguel.carvalho/dev/datacamp/1_introduction_to_data_engineering/datasets:
#
# /Users/miguel.carvalho/dev/datacamp/1_introduction_to_data_engineering/notes:
# 1_introduction_to_data_engineering-1_introduction_to_data_engineering.ipynb
#
# /Users/miguel.carvalho/dev/datacamp/1_introduction_to_data_engineering/slides:
# 1_1_introduction_to_data_engineering.pdf
# 1_2_data_engineering_toolbox.pdf
# 1_3_etl.pdf
# 1_4_case_study.pdf
#
# /Users/miguel.carvalho/dev/datacamp/2_streamlined_data_ingestion_with_pandas:
# datasets/ notes/    slides/
#
# /Users/miguel.carvalho/dev/datacamp/2_streamlined_data_ingestion_with_pandas/datasets:
# data.db                         fcc-new-coder-survey.xlxs.xlsx
# dhs_data.json                   vt_tax_data_2016.csv
#
# /Users/miguel.carvalho/dev/datacamp/2_streamlined_data_ingestion_with_pandas/notes:
# 2_1_introduction_to_flat_files.ipynb
#
# /Users/miguel.carvalho/dev/datacamp/2_streamlined_data_ingestion_with_pandas/slides:
# 2_1_importing_data_from_flat_files.pdf
# 2_2_importing_data_from_excel_files.pdf
# 2_3_importing_data_from_databases.pdf
# 2_4_importing_data_from_json_and_working_with_apis.pdf
#
# /Users/miguel.carvalho/dev/datacamp/3_software_engineering_for_data_scientists_in_python:
# datasets/ notes/    slides/
#
# /Users/miguel.carvalho/dev/datacamp/3_software_engineering_for_data_scientists_in_python/datasets:
# nay_pep8.py  yay_pep8.py
#
# /Users/miguel.carvalho/dev/datacamp/3_software_engineering_for_data_scientists_in_python/notes:
# 3_software_engineering_for_data_scientists_in_python.ipynb
# package_name/
#
# /Users/miguel.carvalho/dev/datacamp/3_software_engineering_for_data_scientists_in_python/notes/package_name:
# __init__py   document.py  my_class.py  utils.py
#
# /Users/miguel.carvalho/dev/datacamp/3_software_engineering_for_data_scientists_in_python/slides:
#
# /Users/miguel.carvalho/dev/datacamp/5_introduction_to_shell:
# notes/  slides/
#
# /Users/miguel.carvalho/dev/datacamp/5_introduction_to_shell/notes:
# 5_introduction_to_shell.ipynb
#
# /Users/miguel.carvalho/dev/datacamp/5_introduction_to_shell/slides:
#
# /Users/miguel.carvalho/dev/stuff:
# README.md  analysis/  process/   prod/      sandbox/   scripts/   templates/
#
# /Users/miguel.carvalho/dev/stuff/analysis:
# Machine_Ebates_Case_Study/ monitoring_usage/
# asa/                       old_client_notebooks/
# aso_dashboards/
#
# /Users/miguel.carvalho/dev/stuff/analysis/Machine_Ebates_Case_Study:
# Ebates_Data_Analysis.ipynb
#
# /Users/miguel.carvalho/dev/stuff/analysis/asa:
# old/
#
# /Users/miguel.carvalho/dev/stuff/analysis/asa/old:
# conversion_drop_analysis.ipynb
#
# /Users/miguel.carvalho/dev/stuff/analysis/aso_dashboards:
# twitter_dashboard.ipynb
#
# /Users/miguel.carvalho/dev/stuff/analysis/monitoring_usage:
# app_radar_api_usage.ipynb  gcp_bucket_size.ipynb
#
# /Users/miguel.carvalho/dev/stuff/analysis/old_client_notebooks:
# ebates/  ebay/    gumtree/ mercari/ sephora/
#
# /Users/miguel.carvalho/dev/stuff/analysis/old_client_notebooks/ebates:
# performance_charts-ebates-201810.ipynb
#
# /Users/miguel.carvalho/dev/stuff/analysis/old_client_notebooks/ebay:
# performance_charts-py3-ebay.ipynb
#
# /Users/miguel.carvalho/dev/stuff/analysis/old_client_notebooks/gumtree:
# performance_charts-gumtree-201810.ipynb
#
# /Users/miguel.carvalho/dev/stuff/analysis/old_client_notebooks/mercari:
# performance_charts-mercari-201809.ipynb
#
# /Users/miguel.carvalho/dev/stuff/analysis/old_client_notebooks/sephora:
# performance_charts-sephora-201810.ipynb
#
# /Users/miguel.carvalho/dev/stuff/process:
# app_radar_weekly_pull/    bq_kw_ranks_insert/       gcp_token_reauthenticate/
#
# /Users/miguel.carvalho/dev/stuff/process/app_radar_weekly_pull:
# other/                   pull_weekly_ranks.ipynb
#
# /Users/miguel.carvalho/dev/stuff/process/app_radar_weekly_pull/other:
# create_temporary_database.ipynb  manage_keywords-test.ipynb
#
# /Users/miguel.carvalho/dev/stuff/process/bq_kw_ranks_insert:
# insert_csv_to_kw_ranks_bq.ipynb
#
# /Users/miguel.carvalho/dev/stuff/process/gcp_token_reauthenticate:
# create_gp_console_tokens.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod:
# app_info_setup/               keyword_bank_relevancy_score/
# apple_sov_processing/         learnings_reports/
# asa_analysis/                 market_analysis/
# asa_sov/                      optimisation_reports/
# bokeh_dashboards/             performance_charts/
# competitor_report/            radar_graphs/
# console_data_processing/      review_analysis/
# creative_conversion_report/   search_ads/
# data_studio_dashboards/       smokey_robinson/
# experiments_reports/
#
# /Users/miguel.carvalho/dev/stuff/prod/app_info_setup:
# app_info_manage.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/apple_sov_processing:
# apple_sov_processing.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/asa_analysis:
# asa-keyword_volume_estimator.ipynb     asa-sov_total.ipynb
# asa-paid_incrementality.ipynb          creative_set_testing_v2.ipynb
# asa-predict_keyword_search_info.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/asa_sov:
# asa_sov_setup.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/bokeh_dashboards:
# __interactive_client_dashboard.ipynb  output/
# _dashboard_v1.ipynb                   plot_data/
# bokeh_dashboard-py3.ipynb             seriesFilter.js
# dashboard_v1.ipynb                    theasoco.png
#
# /Users/miguel.carvalho/dev/stuff/prod/bokeh_dashboards/output:
# accuweather.html  betway.html       ebates.html
#
# /Users/miguel.carvalho/dev/stuff/prod/bokeh_dashboards/plot_data:
# accuweather/ betway/      ebates/
#
# /Users/miguel.carvalho/dev/stuff/prod/bokeh_dashboards/plot_data/accuweather:
# 300048137_de-DE.txt                com.accuweather.android_en-CA.txt
# 300048137_en-CA.txt                com.accuweather.android_en-GB.txt
# 300048137_en-GB.txt                com.accuweather.android_en-IN.txt
# 300048137_en-US.txt                com.accuweather.android_en-US.txt
# 300048137_ko-KR.txt                com.accuweather.android_ko-KR.txt
# 300048137_pt-BR.txt                com.accuweather.android_pt-BR.txt
# com.accuweather.android_de-DE.txt  com.accuweather.android_ru-RU.txt
#
# /Users/miguel.carvalho/dev/stuff/prod/bokeh_dashboards/plot_data/betway:
# 538775096_de-DE.txt          550442071_en-GB.txt
# 538775096_en-GB.txt          com.betway.casino_en-GB.txt
# 538775096_sv-SE.txt          com.betway.sports_en-GB.txt
# 550442071_de-DE.txt
#
# /Users/miguel.carvalho/dev/stuff/prod/bokeh_dashboards/plot_data/ebates:
# 723134859_en-US.txt   com.ebates_en-US.txt
#
# /Users/miguel.carvalho/dev/stuff/prod/competitor_report:
# competitor_report-py3-MASTER-CUSTOM_DATES.ipynb
# competitor_report-py3-MASTER-Copy1.ipynb
# competitor_report-py3-MASTER.ipynb
# competitor_report-py3-MASTER_dev.ipynb
# competitor_report-py3-MASTER_laura.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/console_data_processing:
# Console_Processing_Updated.ipynb  temp/
#
# /Users/miguel.carvalho/dev/stuff/prod/console_data_processing/temp:
# console_data_processing-py3-asa_impressions.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/creative_conversion_report:
# creative_conversion_report-Farfetch_Jan2020.ipynb
# creative_conversion_report-Folio.ipynb
# creative_conversion_report-FuseboxLoveIsland.ipynb
# creative_conversion_report-Nectar_Sainsys.ipynb
# creative_conversion_report-OLX_iOS.ipynb
# creative_conversion_report-Sephora.ipynb
# creative_conversion_report-audiobooks.ipynb
# creative_conversion_report-duolingo.ipynb
# creative_conversion_report-trainline_Jan20.ipynb
# creative_conversion_report_Farfetch.ipynb
# creative_conversion_report_Flipboard.ipynb
# creative_conversion_report_GlowBaby.ipynb
# creative_conversion_report_JCPenney.ipynb
# creative_conversion_report_Trainline.ipynb
# creative_conversion_report_Trainline_iOS.ipynb
# creative_conversion_report_babylon.ipynb
# creative_conversion_report_easypark.ipynb
# creative_conversion_report_sun_racing.ipynb
# creative_conversion_report_template-Farfetch_dec2k19.ipynb
# creative_conversion_report_template_laura-Copy1.ipynb
# creative_conversion_report_template_laura.ipynb
# v1/
#
# /Users/miguel.carvalho/dev/stuff/prod/creative_conversion_report/v1:
# Creative_Conversion_Report_V3.0_PY3_PORT.ipynb
# Creative_Conversion_Report_V3.0_PY3_PORT_CUSTOMDATES.ipynb
# new_creative_conversion_report-template.ipynb
# py3_creative_conversion_report_gp_new.ipynb
# py3_creative_conversion_report_vA.ipynb
# py3_creative_conversion_report_vA_manual.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/data_studio_dashboards:
# ASO_dashboard_data_update-Master-WR.ipynb
# adhoc/
# create_aso_dashboard_data.ipynb
# create_aso_dashboard_data_nov19.ipynb
# create_aso_dashboard_keyword_data.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/data_studio_dashboards/adhoc:
# twitter_dashboard_reshape.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/experiments_reports:
# experiments_report-py3-MASTER-BQ.ipynb  experiments_report-py3-MASTER.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/keyword_bank_relevancy_score:
# Keyword_Bank-py3-MASTER.ipynb
# Relevancy_Score_Updated_laura.ipynb
# Relvancy_Score_Updated_laura.ipynb
# keyword_creation_and_relevancy-py3-MASTER.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/learnings_reports:
# learnings_report-py3-MASTER-BQ.ipynb  learnings_report-py3-MASTER.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/market_analysis:
# market_recommendations-py3-MASTER-Copy1.ipynb
# market_recommendations-py3-MASTER.ipynb
# market_recommendations-py3.5-MASTER.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/optimisation_reports:
# optimisation_report-Papermill-MASTER.ipynb*
# optimisation_report-py3-BigQuery-MASTER-WR_Update.ipynb
# optimisation_report-py3-BigQuery-MASTER.ipynb*
# optimisation_report-py3-MASTER-BigQueryLaura.ipynb*
# optimisation_report-py3-MASTER-rework.ipynb*
# optimisation_report-py3-MASTER.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/performance_charts:
# PERFORMANCE_REVIEW_SOFI2020.ipynb
# PR_Archives/
# performace_charts_v3-Rebates.ipynb
# performace_charts_v3.5_Duolingo-GP.ipynb
# performace_charts_v3.5_Duolingo.ipynb
# performace_charts_v3.5_Folio.ipynb
# performace_charts_v3.5_Hulu_2020.ipynb
# performace_charts_v3.5_Kinedu_2020.ipynb
# performace_charts_v3.5_MASTER-Audiobooks.ipynb
# performace_charts_v3.5_MASTER-BABYLON.ipynb
# performace_charts_v3.5_MASTER-BLACKFRIDAY.ipynb
# performace_charts_v3.5_MASTER-Clickher.ipynb
# performace_charts_v3.5_MASTER-DOSH.ipynb
# performace_charts_v3.5_MASTER-FARFETCH.ipynb
# performace_charts_v3.5_MASTER-OLX.ipynb
# performace_charts_v3.5_MASTER-PRICELINE.ipynb
# performace_charts_v3.5_MASTER-SPOTIFY.ipynb
# performace_charts_v3.5_MASTER_WR.ipynb
# performace_charts_v3.5_Monese.ipynb
# performace_charts_v3.5_Stitch-Fix-Q4.ipynb
# performace_charts_v3.6_MASTER-BEANS.ipynb
# performace_charts_v3.6_MASTER-EBATES-QSR.ipynb
# performace_charts_v3.6_MASTER-test.ipynb
# performace_charts_v3.6_MASTER.ipynb
# performace_charts_v3_JC_Penny.ipynb
# performace_charts_v3_MASTER-Accuweather-Copy1.ipynb
# performace_charts_v3_MASTER-Accuweather.ipynb
# performace_charts_v3_MASTER-Dosh.ipynb
# performace_charts_v3_MASTER-Ebates.ipynb
# performace_charts_v3_MASTER-Farfetch.ipynb
# performace_charts_v3_MASTER-LVR.ipynb
# performace_charts_v3_MASTER-SoFi.ipynb
# performace_charts_v3_MASTER-Trainline-Copy1.ipynb
# performace_charts_v3_MASTER-Trainline.ipynb
# performace_charts_v3_MASTER-test.ipynb
# performace_charts_v3_MASTER_eBay.ipynb
# performace_charts_v3_Storm-Copy1.ipynb
# performace_charts_v3_Storm.ipynb
# performace_charts_v3_TWC.ipynb
# v2/
#
# /Users/miguel.carvalho/dev/stuff/prod/performance_charts/PR_Archives:
# performace_charts_Ebay (AU,DE,UK)_v2.ipynb
# performace_charts_Ebay_v2.ipynb
# performace_charts_Farfetch_v2.ipynb
# performace_charts_Final_Version-Spotify.ipynb
# performace_charts_Final_Version-Urbansitter_v2.ipynb
# performace_charts_Glassdoor_v2.ipynb
# performace_charts_MASTER-BK_v2.ipynb
# performace_charts_MASTER-Copy1_v2.ipynb
# performace_charts_MASTER-test_v2.ipynb
# performace_charts_MASTER-v2-Babylon.ipynb
# performace_charts_MASTER-v2-Copy1.ipynb
# performace_charts_MASTER_v2.ipynb
# performace_charts_Sephora_v2.ipynb
# performace_charts_v2_Flipboard.ipynb
# performace_charts_v2_Laura.ipynb
# performace_charts_v3_MASTER-Freebird.ipynb
# performace_charts_v3_MASTER-Sideline_[Pinger].ipynb
# performance_charts-py3-AccuWeather2019.ipynb
# performance_charts-py3-AccuWeather20190611-GP.ipynb
# performance_charts-py3-AccuWeather20190611.ipynb
# performance_charts-py3-Accuweather-20190531.ipynb
# performance_charts-py3-Accuweather-2019Q1.ipynb
# performance_charts-py3-Betway.ipynb
# performance_charts-py3-Burger_King.ipynb
# performance_charts-py3-Burger_King_v2.ipynb
# performance_charts-py3-CasinoMansion.ipynb
# performance_charts-py3-Drop.ipynb
# performance_charts-py3-Drop2019.ipynb
# performance_charts-py3-Farfetch.ipynb
# performance_charts-py3-Flipboard.ipynb
# performance_charts-py3-Freeletics.ipynb
# performance_charts-py3-GUARDIAN.ipynb
# performance_charts-py3-Gaia_2.ipynb
# performance_charts-py3-Glow-Baby.ipynb
# performance_charts-py3-Glow_Baby.ipynb
# performance_charts-py3-HIST.ipynb
# performance_charts-py3-HISTORY.0
# performance_charts-py3-HISTORY_old.ipynb
# performance_charts-py3-Hotels.com.ipynb
# performance_charts-py3-JOOM_WR.ipynb
# performance_charts-py3-Joom_2.ipynb
# performance_charts-py3-KKL.ipynb
# performance_charts-py3-MASTER-AUDIOMACK.ipynb
# performance_charts-py3-MASTER-Accuweather.ipynb
# performance_charts-py3-MASTER-EBATES-2019.ipynb
# performance_charts-py3-MASTER-Ebates.ipynb
# performance_charts-py3-MASTER-EbatesBF.ipynb
# performance_charts-py3-MASTER-LIFESUM-APRIL.ipynb
# performance_charts-py3-MASTER-Lifesum.ipynb
# performance_charts-py3-MASTER-Luno.ipynb
# performance_charts-py3-MASTER-Sephora.ipynb
# performance_charts-py3-MASTER-Strava.ipynb
# performance_charts-py3-MASTER-Tophatter.ipynb
# performance_charts-py3-MASTER-Twitch-Copy1.ipynb
# performance_charts-py3-MASTER-Twitch.ipynb
# performance_charts-py3-MASTER-V2-TICKETMASTER.ipynb
# performance_charts-py3-MASTER-V2.0.ipynb
# performance_charts-py3-MASTER-Zappos.ipynb
# performance_charts-py3-MASTER-ZocDoc.ipynb
# performance_charts-py3-MASTER-eBay.ipynb
# performance_charts-py3-MASTER-joox.ipynb
# performance_charts-py3-MASTER.ipynb
# performance_charts-py3-Match.com.ipynb
# performance_charts-py3-Mercari-Copy1.ipynb
# performance_charts-py3-Rebates.ipynb
# performance_charts-py3-Sephora.ipynb
# performance_charts-py3-Sephora_ASA_2019.ipynb
# performance_charts-py3-Shopkick.ipynb
# performance_charts-py3-Showroomprive.ipynb
# performance_charts-py3-Snapchat.ipynb
# performance_charts-py3-SoFi.ipynb
# performance_charts-py3-Spotify-201907-Copy1.ipynb
# performance_charts-py3-Spotify-201907.ipynb
# performance_charts-py3-Spotify.ipynb
# performance_charts-py3-StitchFix-20190613.ipynb
# performance_charts-py3-StitchFix.ipynb
# performance_charts-py3-StitchFix_2019_WR.ipynb
# performance_charts-py3-Strava.ipynb
# performance_charts-py3-Sun_Racing.ipynb
# performance_charts-py3-TWC.ipynb
# performance_charts-py3-TWC_2019.ipynb
# performance_charts-py3-TWC_Con.ipynb
# performance_charts-py3-The-League.ipynb
# performance_charts-py3-WIP.ipynb
# performance_charts-py3-accuweather_seasonal.ipynb
# performance_charts-py3-betway-201904.ipynb
# performance_charts-py3-eBay2019.ipynb
# performance_charts-py3-eBay2019US.ipynb
# performance_charts-py3-linkedin.ipynb
# performance_charts-py3-sleep_cycle.ipynb
# performance_charts-py3-sleep_cycle_case_study.ipynb
# performance_charts-py3-sleepcycle.ipynb
# template_performance_charts_v2-1.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/performance_charts/v2:
# performace_charts_Final_Version-Spotify-Dev.ipynb
# performace_charts_Final_Version.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/radar_graphs:
# Radar Graph PY3.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/review_analysis:
# Review_Insights.ipynb    Review_Processing.ipynb  Reviews_Graphs.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/search_ads:
# autobidder/       generators/       merger/
# discovery/        internal/         other_reports/
# fetch/            master_notebooks/ package/
#
# /Users/miguel.carvalho/dev/stuff/prod/search_ads/autobidder:
# autobidder_realtime_v2.ipynb  keywords_pauser.ipynb
# autobidder_v2.ipynb           weekend_rules.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/search_ads/discovery:
# discovery_to_exact.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/search_ads/fetch:
# all/    single/
#
# /Users/miguel.carvalho/dev/stuff/prod/search_ads
# r_keywords_267608897.json
# r_keywords_267739232.json
# r_keywords_267843826.json
# r_keywords_269201919.json
# r_keywords_269206779.json
# r_keywords_269253019.json
# r_keywords_269256516.json
# r_keywords_269340566.json
# r_keywords_269341607.json
# r_keywords_273426494.json
# r_keywords_35095965.json
# r_keywords_35115093.json
# r_keywords_35116757.json
# r_keywords_35116759.json
# r_keywords_49824023.json
# r_keywords_49824086.json
# r_keywords_49824124.json
# r_keywords_49824125.json
# r_keywords_49828122.json
# r_keywords_49828581.json
# report_fetch_jenny.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/search_ads/fetch/single:
# fetch-appsflyer-in_app_events-single.ipynb
# fetch-appsflyer_installs-single.ipynb
# fetch_tracking_changes.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/search_ads/generators:
# all/    single/
#
# /Users/miguel.carvalho/dev/stuff/prod/search_ads/generators/all:
# generator-asa_report_campaign.ipynb
# generator-asa_report_creative_sets.ipynb
# generator-asa_report_keyword.ipynb
# generator-asa_report_search_terms.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/search_ads/generators/single:
# generator-asa_daily_caps-single.ipynb
# generator-asa_report_adgroup-month.ipynb
# generator-asa_report_adgroup.ipynb
# generator-asa_report_campaign-single-month.ipynb
# generator-asa_report_campaign-single-v2.ipynb
# generator-asa_report_campaign-single.ipynb
# generator-asa_report_creative_sets-single-month.ipynb
# generator-asa_report_creative_sets-single.ipynb
# generator-asa_report_hotels.ipynb
# generator-asa_report_keyword-single-month.ipynb
# generator-asa_report_keyword-single.ipynb
# generator-asa_report_mmp.ipynb
# generator-asa_report_search_terms-single-month.ipynb
# generator-asa_report_search_terms-single.ipynb
# generator-asa_reports.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/search_ads/internal:
# hotelscom-pacing.ipynb  pacing_report.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/search_ads/master_notebooks:
# get-pip.py                      master_notebook.ipynb
# master_autobidder.ipynb         master_notebook_20190225.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/search_ads/merger:
# generator-hotels_internal_report.ipynb
# merger-adjust.ipynb
# merger-appsflyer-in_app_events-Copy1.ipynb
# merger-appsflyer-testin_events.ipynb
# merger-appsflyer-v2.ipynb
# merger-appsflyer.ipynb
# merger-hotelscom-20181211-raw_report-daily_lte-gbv.ipynb
# merger-hotelscom-20181211-raw_report-daily_lte.ipynb
# merger-hotelscom-20181211-raw_report-monthly_lte.ipynb
# merger-hotelscom-20181211-raw_report.ipynb
# merger-hotelscom-20181211.ipynb
# merger-tune.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/search_ads/other_reports:
# appsflyer_cohorts.ipynb             kochava_cohorts.ipynb
# branch_cohorts.ipynb                reports-hotelscom-lte_add_on.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/search_ads/package:
# search_ads.ipynb     search_ads_v2.ipynb
#
# /Users/miguel.carvalho/dev/stuff/prod/smokey_robinson:
# Tracked_Keywords - Smokey_Robinson_v2 (Manual Backup Pull).ipynb
# Tracked_Keywords - Smokey_Robinson_v2.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox:
# andras/   devrishi/ laura/    miguel/   pavlo/    warwick/
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras:
# analysis/         projects/         scratchpad.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/analysis:
# asa_analysis/          asocore_ranks_test/    hotels_reanalysis/
# aso_performance_audit/ fti_calc/
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/analysis/asa_analysis:
# Untitled.ipynb                      competitors_sov.ipynb
# Volume_Regression_Model_102019.pkl  estimated_spend.ipynb
# _SORT/                              market_share_estimator.ipynb
# accuweather_asa_201906.ipynb        smokey_robinson_veg.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/analysis/asa_analysis/_SORT:
# The _Tool_.ipynb             asa_cannib_hotels.ipynb
# Volume_Regression_Model.pkl  asa_cannibalization/
# asa-aso_ranks.ipynb          asa_qsr.ipynb
# asa-trend_comparison/        data/
# asa_apple_sov.ipynb          kw_dash.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/analysis/asa_analysis/_SORT/asa-trend_comparison:
# accuweather-spend_v_conversions_201811-CA.png
# accuweather-spend_v_conversions_201811-DE.png
# accuweather-spend_v_conversions_201811-GB.png
# accuweather-spend_v_conversions_201811-KR.png
# accuweather-spend_v_conversions_201811-US.png
# asa-trend_comparison.ipynb
# hotelscom-spend_v_conversions_201811.png
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/analysis/asa_analysis/_SORT/asa_cannibalization:
# _data_processing_x.ipynb
# _sa_cannibalisation-MASTER (1).ipynb
# _sa_cannibalisation-MASTER.ipynb
# asa_cannibalization-1_console_data_processing.ipynb
# asa_cannibalization-2_cannibalization_graphs.ipynb
# asa_cannibalization-MAIN.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/analysis/asa_analysis/_SORT/data:
# AccuWeather_Historical_SOV_Q1_2019.xlsx
# Ebates_Historical_SOV_Q1_2019.xlsx
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/analysis/aso_performance_audit:
# aso_performance-ios.ipynb  data_processing.ipynb
# data_old-ios.png           performance_review.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/analysis/asocore_ranks_test:
# asocore_machine.pem        asocore_script_test.ipynb
# asocore_ranks.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/analysis/fti_calc:
# fti_calculation.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/analysis/hotels_reanalysis:
# hotels_re_201811.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/projects:
# app_store_connect_api/ crawl_module/          gp_reviews/
# appradar_gcp/          creative_analysis/     kubectl/
# appsflyer_process/     dag_gpc/               selenium/
# asyncio_test/          docker_test/           sendgrid/
# cat_rank/              gcp/                   simulations/
# composer/              gcp-airflow/           xkcd/
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/projects/app_store_connect_api:
# AuthKey_W5NFKP42FQ.p8        app_store_connect_api.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/projects/appradar_gcp:
# appradar_gcp.py
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/projects/appsflyer_process:
# Untitled.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/projects/asyncio_test:
# asyncio_test.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/projects/cat_rank:
# cat_rank-apptweak_scrape_and_plot.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/projects/composer:
# composer.py              composer_uploader.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/projects/crawl_module:
# crawl_module.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/projects/creative_analysis:
# 2-color_analysis.ipynb
# creative_asset_scraping_datalab.ipynb
# projects_creative_analysis_2-color_analysis.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/projects/dag_gpc:
# template_performance_charts_v2.ipynb  tutorial_mk_package.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/projects/docker_test:
# Dockerfile        requirements.txt  useragents.txt
# proxies.txt       settings.py
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/projects/gcp:
# bq_table_upload.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/projects/gcp-airflow:
# Untitled.ipynb                 create_bq_ard_table.ipynb
# Untitled1.ipynb                dag-app_radar_api.py
# accu_dash.ipynb                data_test_1.json
# airflow.ipynb                  gcp-test-1-646a48927ff7.json
# airflow_setup.ipynb            gcp_test.ipynb
# app_radar_pipeline_test.ipynb  gcs-uploader.json
# bq-client.json                 quickstart.py
# bq_asa_temp.ipynb              scripts_pull_data_gpc.py
# bquery_test.ipynb              temp.json
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/projects/gp_reviews:
# Google_Play_Reviews_Pull.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/projects/kubectl:
# Dockerfile      hello-pod.yaml  hello.py
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/projects/selenium:
# old/
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/projects/selenium/old:
# scrape_app_store_connect.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/projects/sendgrid:
# sendgrid.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/projects/simulations:
# internal_air_temperature__spains_dwelling.png
# internal_air_temperature__spains_dwelling__2050_june__october.png
# internal_air_temperature__spains_dwelling__2080_june__october.png
# internal_air_temperature__spains_dwelling__today_june__october.png
# internal_air_temperature__uks_dwelling.png
# internal_air_temperature__uks_dwelling__2050_june__october.png
# internal_air_temperature__uks_dwelling__2080_june__october.png
# internal_air_temperature__uks_dwelling__today_june__october.png
# simulations.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/andras/projects/xkcd:
# Humor-Sans.ttf  xkcd.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/devrishi:
# Template.ipynb*
# Tracked_Keywords - Smokey_Robinson_v2.ipynb
# Untitled.ipynb
# add_hoc/
# app_tweak_api/
# d2d/
# projects/
# py2/
# wario/
#
# /Users/miguel.carvalho/dev/stuff/sandbox/devrishi/add_hoc:
# BQ Graphs.ipynb*
# Event Keywords.ipynb*
# Keyword_Graphs.ipynb*
# Keyword_Performance_Graphs_AppRadar.ipynb*
# app_radar pull.ipynb
# bquery_test.ipynb*
# comp_report_manual-Copy1.ipynb
# comp_report_manual.ipynb*
# mig-kw_data.ipynb
# munger.5.ipynb*
# super_secret_devrishi_project.ipynb*
#
# /Users/miguel.carvalho/dev/stuff/sandbox/devrishi/app_tweak_api:
# App Tweak API - Image Processing.ipynb*
# App Tweak API - Metadata Optimisation .ipynb*
#
# /Users/miguel.carvalho/dev/stuff/sandbox/devrishi/d2d:
# Client Onboarding.ipynb*    onboarding-gspread.ipynb*
# bucket_to_filestream.ipynb*
#
# /Users/miguel.carvalho/dev/stuff/sandbox/devrishi/projects:
#  performance_charts_v3_MASTER_slide_test.ipynb*
# DS - Creative_Conversion_Report_PY3.ipynb*
# PRTG.ipynb*
# PY_2_SLIDE.ipynb*
# R_R scraper .ipynb*
# performace_charts_v3.5_MASTER-PY2SLIDE-ORIG.ipynb
# performace_charts_v3.5_MASTER-PY2SLIDE.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/devrishi/py2:
# Creative Conversion - BENCHMARK 1.0.ipynb
# Creative_Conversion_Report_V2-BLACK FRIDAY.ipynb
# Creative_Conversion_Report_V2-Copy1.0.ipynb
# Creative_Conversion_Report_V2-DASHED_LINE_MASTER.ipynb
# Creative_Conversion_Report_V3 - ALL CHANNELS.ipynb
# Creative_Conversion_Report_V3-Conversion_Rate_Adjusted.ipynb
# Creative_Conversion_Report_V3.0_PY3_PORT.ipynb
# Keyword_Performance_Graphs_AppRadar-Sephora.ipynb
# Metadata Learnings Report Notebook - V1-Prep Pull.ipynb
# Metadata Learnings Report Notebook - V1.0.ipynb
# Metadata_Experiments_Report_V1.0.ipynb
# Metadata_Experiments_Report_V1.2.ipynb
# Optimisation_Report_V2.2.ipynb
# apptweak_api.ipynb
# competitor_insights-radar.ipynb
# conversion-MASTER.ipynb
# conversion-SingleDaysRemoved.ipynb
# dashboard-process_console_data.ipynb
# data_processing-consoles.ipynb
# data_processing-consoles_updated.ipynb
# declared_keyword_builder.ipynb
# farfetch_dashboard_keywords.ipynb
# featuring-MASTER.ipynb
# ipi_report.ipynb
# sa_cannibalisation-MASTER.ipynb
# scrape_gp_install_bands.ipynb
# search_ads_auto_bidder.ipynb
# search_ads_campaign_upload.ipynb
# search_ads_discovery_to_exact.ipynb
# search_ads_keyword_movement.ipynb
# search_ads_reports.ipynb
# search_ads_reports_stripped.ipynb
# search_ads_utility_functions.ipynb
# slack bot py3.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/devrishi/wario:
# build/          setup.py*       wario/          wario.egg-info/
#
# /Users/miguel.carvalho/dev/stuff/sandbox/devrishi/wario/build:
# lib/
#
# /Users/miguel.carvalho/dev/stuff/sandbox/devrishi/wario/build/lib:
# wario/
#
# /Users/miguel.carvalho/dev/stuff/sandbox/devrishi/wario/build/lib/wario:
# __init__.py
#
# /Users/miguel.carvalho/dev/stuff/sandbox/devrishi/wario/wario:
# __init__.py
#
# /Users/miguel.carvalho/dev/stuff/sandbox/devrishi/wario/wario.egg-info:
# PKG-INFO              dependency_links.txt
# SOURCES.txt           top_level.txt
#
# /Users/miguel.carvalho/dev/stuff/sandbox/laura:
# BQ Graphs.ipynb
# Rebates_data_processing.ipynb
# Review Analysis Notebook - Twitter.ipynb
# Review Analysis Notebook - v1- Betway Casino-Copy1.ipynb
# active_users_chart/
# apptweak_staturegraph/
# bucket_to_filestream.ipynb
# initial_client_metrics.ipynb
# optimisation_report-py3-MASTER-BigQuery-Final_LW-Mamba_edit.ipynb
# orzo/
# performace_charts_v3_MASTER-FF-GP.ipynb
# performace_charts_v3_MASTER-FF-iOS.ipynb
# temple_burger-aka-initial_client_audit/
# test/
#
# /Users/miguel.carvalho/dev/stuff/sandbox/laura/active_users_chart:
# active_users_chart.ipynb
# active_users_chart_mansionbet.ipynb
# fti_calculation.ipynb
# twitter__gp__first_time_installs_ratio_over_time__q2_2019.png
#
# /Users/miguel.carvalho/dev/stuff/sandbox/laura/apptweak_staturegraph:
# cat_rank-apptweak_scrape_and_plot.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/laura/orzo:
# pasta_&_rice_correlations-AccuWeather.ipynb
# pasta_&_rice_correlations-Babylon.ipynb
# pasta_&_rice_correlations-Ebates.ipynb
# pasta_&_rice_correlations-Farfetch.ipynb
# pasta_&_rice_correlations-Hotels.ipynb
# pasta_&_rice_correlations-Priceline-Copy1.ipynb
# pasta_&_rice_correlations-Priceline.ipynb
# pasta_&_rice_correlations-SoFi.ipynb
# pasta_&_rice_correlations.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/laura/temple_burger-aka-initial_client_audit:
# DnL-initial_client_audit-MASTER.ipynb  DnL-initial_client_audit-V2.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/laura/test:
# 1st notebook.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/miguel:
# 1_introduction_to_data_engineering-1_introduction_to_data_engineering.ipynb
# Dataflow.ipynb
# Untitled.ipynb
# Untitled1.ipynb
# Untitled10.ipynb
# Untitled11.ipynb
# Untitled12.ipynb
# Untitled13.ipynb
# Untitled14.ipynb
# Untitled15.ipynb
# Untitled16.ipynb
# Untitled17.ipynb
# Untitled18.ipynb
# Untitled19.ipynb
# Untitled2.ipynb
# Untitled20-Copy1.ipynb
# Untitled20.ipynb
# Untitled21.ipynb
# Untitled22.ipynb
# Untitled23.ipynb
# Untitled24.ipynb
# Untitled25.ipynb
# Untitled26.ipynb
# Untitled27.ipynb
# Untitled28.ipynb
# Untitled29.ipynb
# Untitled3.ipynb
# Untitled30.ipynb
# Untitled31.ipynb
# Untitled32.ipynb
# Untitled33.ipynb
# Untitled34.ipynb
# Untitled4.ipynb
# Untitled5.ipynb
# Untitled6.ipynb
# Untitled7.ipynb
# Untitled8.ipynb
# Untitled9.ipynb
# adjust-merge_data-Copy1.ipynb
# adjust-merge_data.ipynb
# airflow-appsflyer-clean_mmp.ipynb
# airflow-appsflyer-clean_reports.ipynb
# airflow-appsflyer-pre_process_reports.ipynb
# airflow-appsflyer-pull_in_app_events_hourly.ipynb
# airflow-ds.ipynb
# airflow-kochava-pre_process_reports.ipynb
# airflow-merge_appsflyer_installs.ipynb
# airflow-new_appsflyer_process.ipynb
# airflow-test_processed_appsflyer_reports.ipynb
# airflow-test_scripts-Copy1.ipynb
# airflow-test_scripts-Copy2.ipynb
# airflow-test_scripts-Copy3.ipynb
# airflow-test_scripts-appsflyer.ipynb
# airflow-test_scripts.ipynb
# analysis-sample_download_of_rankings.ipynb
# appsflyer_merge.ipynb
# aso-analysis-master/
# biquery-sample.ipynb
# branch/
# bulk-add_new_keywords.ipynb
# bulk-change_bids.ipynb
# bulk-change_daily_caps-Copy1.ipynb
# bulk-change_daily_caps.ipynb
# bulk-change_keywords_ebates.ipynb
# bulk-make_adgroup_copies.ipynb
# bulk-new_adgroups_ebates.ipynb
# bulk-repeating_campaigns_for_hotels-Copy1.ipynb
# bulk-repeating_campaigns_for_hotels-Copy2.ipynb
# bulk-repeating_campaigns_for_hotels.ipynb
# bulk-upload_campaigns-Copy1.ipynb
# bulk-upload_campaigns.ipynb
# change_bids_under_armour.ipynb
# clean_processed.ipynb
# client_analysis.ipynb
# composer-clean_keywords.ipynb
# composer-hourly_reports.ipynb
# create_ebates_reports.ipynb
# create_ebates_reports_campaigns_keywords_adgroups.ipynb
# data_engineering_notes.ipynb
# datacamp/
# datacamp-introduction_to_pyspark-getting_to_know_pyspark.ipynb
# datacamp-introduction_to_pyspark-manipulating_data-Copy1.ipynb
# datacamp-introduction_to_pyspark-manipulating_data-getting_started_with_machine_learning_pipelines.ipynb
# datacamp-introduction_to_pyspark-manipulating_data-model_tuning_and_selection.ipynb
# datacamp-introduction_to_pyspark-manipulating_data.ipynb
# datacamp_github/
# depop_ds_search_ads_campaigns_reporting_daily_depop-campaigns_reporting-daily-20200101-20200131.csv
# discovery_to_exact_v2.ipynb
# ebay_merge_test.ipynb
# email_notifications_jenny.ipynb
# football_index_fix.ipynb
# forecast_search_ads_spend.ipynb
# gcs-clean_ups.ipynb
# hotels-airflow-internal_report.ipynb
# hotels-campaigns-merged-20190401-20191031/
# hotels_new_lte_month_type.ipynb
# hotelscom-analysis-creative_set_changes.ipynb
# hotelscom-analysis_q3-Copy1.ipynb
# hotelscom-analysis_q3-campaigns.ipynb
# hotelscom-analysis_q3-keywords.ipynb
# hotelscom-analysis_q3.ipynb
# hotelscom-monthly_analysis.ipynb
# hotelscom-new_excel.ipynb
# internal_report/
# keyword_comparison.csv
# keyword_volume_notification.ipynb
# kochava-test.ipynb
# louis-last_exercise-Copy1.ipynb
# louis-last_exercise.ipynb
# module.ipynb
# process_in_app_events_accuweather.ipynb
# pull_events_accuweather.ipynb
# rakuten-analysis-Copy1.ipynb
# rakuten-analysis.ipynb
# rakuten_notebook.ipynb
# rebates-merge_ftbs.ipynb
# search_ads_two/
# search_ads_uploader.ipynb
# sideline_upload_negative_keywords_from_exact_match.ipynb
# sofi-appsflyer_installs.ipynb
# udacity/
# under_armour.ipynb
# under_armour_bid_changes.csv
# under_armour_bids.csv
# utils-break_in_months.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/miguel/aso-analysis-master:
# aso_analysis.ipynb*        autobidder_thresholds.csv*
# aso_analysis.py*           autobidder_v0.5 (2).ipynb*
# autobidder_logs_2/         requirements.txt*
#
# /Users/miguel.carvalho/dev/stuff/sandbox/miguel/aso-analysis-master/autobidder_logs_2:
# accuweather-autobidder_adjustments_log-20190430.csv*
# accuweather-autobidder_adjustments_log-20190507.csv*
# accuweather-autobidder_adjustments_log-20190509.csv*
# accuweather-autobidder_adjustments_log-20190510.csv*
# accuweather-autobidder_adjustments_log-20190513.csv*
# accuweather-autobidder_adjustments_log-20190517.csv*
# accuweather-autobidder_adjustments_log-20190520.csv*
# accuweather-autobidder_adjustments_log-20190524.csv*
# accuweather-autobidder_adjustments_log-20190528.csv*
# accuweather-autobidder_adjustments_log-20190531.csv*
# accuweather-autobidder_adjustments_log-20190607.csv*
# accuweather-autobidder_adjustments_log-20190612.csv*
# accuweather-autobidder_adjustments_log-20190614.csv*
# accuweather-autobidder_adjustments_log-20190617.csv*
# accuweather-autobidder_adjustments_log-20190624.csv*
# accuweather-autobidder_adjustments_log-20190628.csv*
# accuweather-autobidder_adjustments_log-20190701.csv*
# accuweather-autobidder_adjustments_log-20190705.csv*
# accuweather-autobidder_adjustments_log-20190708.csv*
# accuweather-autobidder_adjustments_log-20190712.csv*
# accuweather-autobidder_adjustments_log-20190722.csv*
# babylon-autobidder_adjustments_log-20190507.csv*
# babylon-autobidder_adjustments_log-20190509.csv*
# babylon-autobidder_adjustments_log-20190510.csv*
# babylon-autobidder_adjustments_log-20190513.csv*
# babylon-autobidder_adjustments_log-20190517.csv*
# babylon-autobidder_adjustments_log-20190520.csv*
# babylon-autobidder_adjustments_log-20190524.csv*
# babylon-autobidder_adjustments_log-20190528.csv*
# babylon-autobidder_adjustments_log-20190531.csv*
# babylon-autobidder_adjustments_log-20190607.csv*
# babylon-autobidder_adjustments_log-20190612.csv*
# babylon-autobidder_adjustments_log-20190614.csv*
# babylon-autobidder_adjustments_log-20190617.csv*
# babylon-autobidder_adjustments_log-20190624.csv*
# babylon-autobidder_adjustments_log-20190628.csv*
# babylon-autobidder_adjustments_log-20190701.csv*
# babylon-autobidder_adjustments_log-20190705.csv*
# babylon-autobidder_adjustments_log-20190708.csv*
# babylon-autobidder_adjustments_log-20190712.csv*
# babylon-autobidder_adjustments_log-20190715.csv*
# babylon-autobidder_adjustments_log-20190719.csv*
# babylon-autobidder_adjustments_log-20190722.csv*
# device_magic-autobidder_adjustments_log-20190507.csv*
# device_magic-autobidder_adjustments_log-20190509.csv*
# device_magic-autobidder_adjustments_log-20190510.csv*
# device_magic-autobidder_adjustments_log-20190513.csv*
# device_magic-autobidder_adjustments_log-20190517.csv*
# device_magic-autobidder_adjustments_log-20190520.csv*
# device_magic-autobidder_adjustments_log-20190524.csv*
# device_magic-autobidder_adjustments_log-20190528.csv*
# device_magic-autobidder_adjustments_log-20190531.csv*
# device_magic-autobidder_adjustments_log-20190607.csv*
# device_magic-autobidder_adjustments_log-20190612.csv*
# device_magic-autobidder_adjustments_log-20190614.csv*
# device_magic-autobidder_adjustments_log-20190617.csv*
# device_magic-autobidder_adjustments_log-20190624.csv*
# device_magic-autobidder_adjustments_log-20190628.csv*
# device_magic-autobidder_adjustments_log-20190701.csv*
# device_magic-autobidder_adjustments_log-20190705.csv*
# device_magic-autobidder_adjustments_log-20190708.csv*
# device_magic-autobidder_adjustments_log-20190712.csv*
# device_magic-autobidder_adjustments_log-20190715.csv*
# device_magic-autobidder_adjustments_log-20190722.csv*
# ebates-autobidder_adjustments_log-20190507.csv*
# ebates-autobidder_adjustments_log-20190509.csv*
# ebates-autobidder_adjustments_log-20190510.csv*
# ebates-autobidder_adjustments_log-20190513.csv*
# ebates-autobidder_adjustments_log-20190517.csv*
# ebates-autobidder_adjustments_log-20190520.csv*
# ebates-autobidder_adjustments_log-20190524.csv*
# ebates-autobidder_adjustments_log-20190528.csv*
# ebates-autobidder_adjustments_log-20190531.csv*
# ebates-autobidder_adjustments_log-20190607.csv*
# ebates-autobidder_adjustments_log-20190612.csv*
# ebates-autobidder_adjustments_log-20190614.csv*
# ebates-autobidder_adjustments_log-20190617.csv*
# ebates-autobidder_adjustments_log-20190624.csv*
# ebates-autobidder_adjustments_log-20190628.csv*
# ebates-autobidder_adjustments_log-20190701.csv*
# ebates-autobidder_adjustments_log-20190705.csv*
# ebates-autobidder_adjustments_log-20190708.csv*
# ebates-autobidder_adjustments_log-20190712.csv*
# ebates-autobidder_adjustments_log-20190722.csv*
# ebay-autobidder_adjustments_log-20190628.csv*
# ebay-autobidder_adjustments_log-20190701.csv*
# ebay-autobidder_adjustments_log-20190705.csv*
# ebay-autobidder_adjustments_log-20190708.csv*
# ebay-autobidder_adjustments_log-20190712.csv*
# ebay-autobidder_adjustments_log-20190722.csv*
# ebay_us-autobidder_adjustments_log-20190507.csv*
# ebay_us-autobidder_adjustments_log-20190509.csv*
# ebay_us-autobidder_adjustments_log-20190510.csv*
# ebay_us-autobidder_adjustments_log-20190513.csv*
# ebay_us-autobidder_adjustments_log-20190517.csv*
# ebay_us-autobidder_adjustments_log-20190520.csv*
# ebay_us-autobidder_adjustments_log-20190524.csv*
# ebay_us-autobidder_adjustments_log-20190528.csv*
# ebay_us-autobidder_adjustments_log-20190531.csv*
# ebay_us-autobidder_adjustments_log-20190607.csv*
# ebay_us-autobidder_adjustments_log-20190612.csv*
# ebay_us-autobidder_adjustments_log-20190614.csv*
# ebay_us-autobidder_adjustments_log-20190617.csv*
# ebay_us-autobidder_adjustments_log-20190624.csv*
# ebay_us-autobidder_adjustments_log-20190628.csv*
# ebay_us-autobidder_adjustments_log-20190701.csv*
# ebay_us-autobidder_adjustments_log-20190705.csv*
# ebay_us-autobidder_adjustments_log-20190708.csv*
# ebay_us-autobidder_adjustments_log-20190712.csv*
# ebay_us-autobidder_adjustments_log-20190722.csv*
# farfetch_uk-autobidder_adjustments_log-20190715.csv*
# farfetch_uk-autobidder_adjustments_log-20190719.csv*
# farfetch_uk-autobidder_adjustments_log-20190722.csv*
# feeld-autobidder_adjustments_log-20190507.csv*
# feeld-autobidder_adjustments_log-20190508.csv*
# feeld-autobidder_adjustments_log-20190510.csv*
# feeld-autobidder_adjustments_log-20190513.csv*
# feeld-autobidder_adjustments_log-20190517.csv*
# feeld-autobidder_adjustments_log-20190520.csv*
# feeld-autobidder_adjustments_log-20190524.csv*
# feeld-autobidder_adjustments_log-20190528.csv*
# feeld-autobidder_adjustments_log-20190531.csv*
# feeld-autobidder_adjustments_log-20190607.csv*
# feeld-autobidder_adjustments_log-20190612.csv*
# feeld-autobidder_adjustments_log-20190614.csv*
# feeld-autobidder_adjustments_log-20190617.csv*
# feeld-autobidder_adjustments_log-20190624.csv*
# feeld-autobidder_adjustments_log-20190628.csv*
# feeld-autobidder_adjustments_log-20190701.csv*
# feeld-autobidder_adjustments_log-20190705.csv*
# feeld-autobidder_adjustments_log-20190708.csv*
# feeld-autobidder_adjustments_log-20190712.csv*
# feeld-autobidder_adjustments_log-20190715.csv*
# feeld-autobidder_adjustments_log-20190719.csv*
# feeld-autobidder_adjustments_log-20190722.csv*
# freebird-autobidder_adjustments_log-20190722.csv*
# holiday_extras-autobidder_adjustments_log-20190503.csv*
# holiday_extras-autobidder_adjustments_log-20190507.csv*
# holiday_extras-autobidder_adjustments_log-20190509.csv*
# holiday_extras-autobidder_adjustments_log-20190510.csv*
# holiday_extras-autobidder_adjustments_log-20190513.csv*
# holiday_extras-autobidder_adjustments_log-20190517.csv*
# holiday_extras-autobidder_adjustments_log-20190520.csv*
# holiday_extras-autobidder_adjustments_log-20190524.csv*
# holiday_extras-autobidder_adjustments_log-20190528.csv*
# holiday_extras-autobidder_adjustments_log-20190531.csv*
# holiday_extras-autobidder_adjustments_log-20190607.csv*
# holiday_extras-autobidder_adjustments_log-20190612.csv*
# holiday_extras-autobidder_adjustments_log-20190614.csv*
# holiday_extras-autobidder_adjustments_log-20190617.csv*
# holiday_extras-autobidder_adjustments_log-20190624.csv*
# holiday_extras-autobidder_adjustments_log-20190628.csv*
# hotelscom-autobidder_adjustments_log-20190503.csv*
# hotelscom-autobidder_adjustments_log-20190507.csv*
# hotelscom-autobidder_adjustments_log-20190509.csv*
# hotelscom-autobidder_adjustments_log-20190510.csv*
# hotelscom-autobidder_adjustments_log-20190513.csv*
# hotelscom-autobidder_adjustments_log-20190517.csv*
# hotelscom-autobidder_adjustments_log-20190520.csv*
# hotelscom-autobidder_adjustments_log-20190524.csv*
# hotelscom-autobidder_adjustments_log-20190528.csv*
# hotelscom-autobidder_adjustments_log-20190531.csv*
# hotelscom-autobidder_adjustments_log-20190607.csv*
# hotelscom-autobidder_adjustments_log-20190612.csv*
# hotelscom-autobidder_adjustments_log-20190614.csv*
# hotelscom-autobidder_adjustments_log-20190617.csv*
# hotelscom-autobidder_adjustments_log-20190624.csv*
# ...
# aind-dl-mac-linux.yml* aind-dl-windows.yml*   requirements.txt*
#
# /Users/miguel.carvalho/dev/stuff/sandbox/miguel/udacity/nanodegree_machine_learning/term_1/projects/practice_projects/naive_bayes_tutorial:
# Bayesian_Inference.ipynb*          images/
# Bayesian_Inference_solution.ipynb* smsspamcollection/
# ReadMe.md*
#
# /Users/miguel.carvalho/dev/stuff/sandbox/miguel/udacity/nanodegree_machine_learning/term_1/projects/practice_projects/naive_bayes_tutorial/images:
# bayes_formula.png*   dqnb.png*            tfidf.png*
# countvectorizer.png* naivebayes.png*
#
# /Users/miguel.carvalho/dev/stuff/sandbox/miguel/udacity/nanodegree_machine_learning/term_1/projects/practice_projects/naive_bayes_tutorial/smsspamcollection:
# SMSSpamCollection* readme*
#
# /Users/miguel.carvalho/dev/stuff/sandbox/miguel/udacity/nanodegree_machine_learning/term_1/projects/smartcab:
# README.md*              smartcab/               visuals.py*
# project_description.md* smartcab.ipynb*
#
# /Users/miguel.carvalho/dev/stuff/sandbox/miguel/udacity/nanodegree_machine_learning/term_1/projects/smartcab/smartcab:
# __init__.py*    environment.py* planner.py*
# agent.py*       images/         simulator.py*
#
# /Users/miguel.carvalho/dev/stuff/sandbox/miguel/udacity/nanodegree_machine_learning/term_1/projects/smartcab/smartcab/images:
# car-black.png*   car-green.png*   car-red.png*     east-west.png*
# car-blue.png*    car-magenta.png* car-white.png*   logo.png*
# car-cyan.png*    car-orange.png*  car-yellow.png*  north-south.png*
#
# /Users/miguel.carvalho/dev/stuff/sandbox/miguel/udacity/nanodegree_machine_learning/term_1/projects/student_intervention:
# README.md*                  student_intervention.ipynb*
# project_description.md*
#
# /Users/miguel.carvalho/dev/stuff/sandbox/pavlo:
# Untitled.ipynb
# Untitled1.ipynb
# ad_hoc_requests/
# app_radar_keyword_tracking/
# archive/
# asa_plots/
# autobidder/
# conversion_window/
# create_ebates_reports_campaigns_keywords_adgroups.ipynb
# datastudio_reports_upgrade/
# kochava_api_schedule_api_report.ipynb
# local.code-workspace
# papermill_for_sandbox_notebooks.ipynb
# relevance_score/
# sov/
#
# /Users/miguel.carvalho/dev/stuff/sandbox/pavlo/ad_hoc_requests:
# 6_month_keyword_agg.ipynb
# Campaigns Weekday vs Weekend.ipynb
# LAT_formula_comparison.ipynb
# Search Term Volume by Week.ipynb
# accuweather-organic_ranking_installs_plots.ipynb
# accuweather-overlay_spend _on_organic_ranks.ipynb
# accuweather-single_keyword_campaign_analysis.ipynb
# accuweather_organic_rank_vs_true_organic_volume.ipynb
# accuweather_search_term_conversions.ipynb
# accuweather_seasonal_keywords.ipynb
# analysis/
# app_radar_comp_data_bq_upload.ipynb
# app_radar_keyword_volume.ipynb
# appsflyer_cohorts.ipynb
# babylon_keywords_nhs_event.ipynb
# bq_update_client_table.ipynb
# bulk_changes/
# clickher-keyword_upload.ipynb
# correlation_analysis_asa_mmp_events.ipynb
# daily_caps_analysis.ipynb
# duplicated_keywords_on_campaigns.ipynb
# ebates-metadata_analysis.ipynb
# ebates_keywords_from_august_fetch.ipynb
# ebates_organic_rank.ipynb
# ebates_q4_2019_qsr.ipynb
# ebay-q4_analysis.ipynb
# ebay_cpa_spike_analysis.ipynb
# ebay_keyword_data_export.ipynb
# email_notifications.ipynb
# estimate_search_volumes.ipynb
# extract_paused_kw_from_autobidder_logs.ipynb
# farfetch_uk-keyword_rank_pre_post_asa.ipynb
# feeld-get_2019_keyword_data.ipynb
# fetch_app_radar_project_id.ipynb
# football_index-appsflyer_data_check.ipynb
# football_index-fetch_agg_ds_data.ipynb
# get_active_client_countries.ipynb
# header_template.ipynb
# hotels_group_testing_adhoc.ipynb
# hotelscom-2020_budget.ipynb
# hotelscom-check_negative_keywords_still_paused.ipynb
# hotelscom-keyword_status_check.ipynb
# hotelscom-keyword_upload_log_creation.ipynb
# hotelscom-live_creative_testing.ipynb
# hotelscom-pause_never_add_keywords.ipynb
# hotelscom_change_max_bids.ipynb
# itrackbites-hour_of_day_conversion_comparison.ipynb
# kochava_cohorting_data.ipynb
# merge_appsflyer_data_from_gcs.ipynb
# module_function/
# organic_uplift.ipynb
# priceline-kochava_cohorting_merge.ipynb
# priceline_duplicate_keywords.ipynb
# prime_day_spend.ipynb
# pull_autobidder_logs.ipynb
# remove_timezone_cols_from_campaigns_hourly.ipynb
# scratchpad.ipynb
# sideline_upload_negative_keywords_from_exact_match.ipynb
# sofi_q3_data.ipynb
# sofi_upload_negative_keywords.ipynb
# sov_app_radar_comparison.ipynb
# upload_file_bucket.ipynb
# upload_new_keywords.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/pavlo/ad_hoc_requests/analysis:
# accuweather/
# accuweather-pitch.ipynb
# accuweather_qsr-20191014.ipynb
# apple_meeting_pre_analysis.ipynb
# asa_creative_set_testing/
# babylon-august_september_event_change_analysis.ipynb
# black_friday_visualisations.ipynb
# ebates-month_on_month_from_sep_2018.ipynb
# hotelscom-optimisation_visualisations.ipynb
# hotelscom-plotting.ipynb
# priceline-brand_trend.ipynb
# priceline-hotel_campaign_lat_analysis.ipynb
# sofi-post_install_analysis.ipynb
# sofi_high_value.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/pavlo/ad_hoc_requests/analysis/accuweather:
# cap_bid_change_analysis.ipynb  resign_analysis.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/pavlo/ad_hoc_requests/analysis/asa_creative_set_testing:
# asa_creative_sets_ab_test_analysis.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/pavlo/ad_hoc_requests/bulk_changes:
# bid_caps.ipynb
# bid_caps_linked_widgets.ipynb
# bulk_bid_changes.ipynb
# bulk_bid_changes_linked_widgets.ipynb
# bulk_pause_keywords.ipynb
# bulk_pause_keywords_linked_widgets.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/pavlo/ad_hoc_requests/module_function:
# app_radar_find_project_app_id.py  gcs_match_on_date.ipynb
# brand_check.py                    keyword_brand_check.ipynb
# discovery_client.ipynb            module_func_test.ipynb
# filter_gcs_files_by_date.py       paginate_dates_func.py
# find_discovery_clients.py
#
# /Users/miguel.carvalho/dev/stuff/sandbox/pavlo/app_radar_keyword_tracking:
# add_app_to_app_radar.ipynb       get_top_keywords.ipynb
# app_radar_keyword_tracker.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/pavlo/archive:
# papermill_for_sandbox_notebooks_(old).ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/pavlo/asa_plots:
# data_process.py
#
# /Users/miguel.carvalho/dev/stuff/sandbox/pavlo/autobidder:
# autobidder_analysis.ipynb             autobidder_v0.32.ipynb
# autobidder_v0.2.1(mmp_inc).ipynb      autobidder_v0.4.ipynb
# autobidder_v0.3.ipynb                 autobidder_v0.5.ipynb
# autobidder_v0.31(high_low_vol).ipynb  autobidder_v0.6.ipynb
# autobidder_v0.31.ipynb                keyword_analysis.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/pavlo/conversion_window:
# conversion_window_download.ipynb      conversions_window_analysis.ipynb
# conversion_window_download_old.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/pavlo/datastudio_reports_upgrade:
# country-list_zip/          mmp_data_ds3_report.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/pavlo/datastudio_reports_upgrade/country-list_zip:
# README.md         data/             datapackage.json
#
# /Users/miguel.carvalho/dev/stuff/sandbox/pavlo/datastudio_reports_upgrade/country-list_zip/data:
# data_json.json          validation_report.json
#
# /Users/miguel.carvalho/dev/stuff/sandbox/pavlo/relevance_score:
# relevance_score.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/pavlo/sov:
# fuzzywuzzy_test.ipynb             sov_merge_all_files.ipynb
# sov test.ipynb                    sov_processing.ipynb
# sov_create_keywords.ipynb         sov_processing_draft.ipynb
# sov_ingest.ipynb                  sov_processing_spend_merge.ipynb
#
# /Users/miguel.carvalho/dev/stuff/sandbox/warwick:
# ASA_Relevancy_Score_Pull.ipynb
# ASA_Returing_Users_vs_FTI.ipynb
# Account Managment_model.sav
# App Store Connect - Pull.ipynb
# ClusterBoot.ipynb
# Conversion_Model_data/
# FF_monthly_processing.ipynb
# Google_Play_Reviews_Pull-Copy1.ipynb
# Google_Play_Reviews_Pull-Copy2.ipynb
# Google_Play_Reviews_Pull.ipynb
# KWRelevancy.ipynb
# KW_Phrase_Creation-Cleaned-NW.ipynb
# KW_Phrase_Creation-Cleaned.ipynb
# KW_Phrase_Creation-Updated-Copy1.ipynb
# KW_Phrase_Creation-Updated.ipynb
# KW_Phrase_Creation.ipynb
# Keyword Creation & Relevancy - Production - v1-Copy1.0.ipynb
# Keyword Creation & Relevancy - Production - v2.0.ipynb
# Keyword_Performance_Graphs_AppRadar.ipynb
# Market Recommendations-Copy1.ipynb
# Market Recommendations-Copy2.ipynb
# Market Recommendations.ipynb
# Read_MMP_data-GP.ipynb
# Read_MMP_data_iOS.ipynb
# Review Analysis Notebook - Twitter.ipynb
# Review Analysis Notebook - v1- Betway Casino.ipynb
# Review Analysis Notebook - v1- Twitter-Copy1.ipynb
# Review Analysis Notebook - v1- Twitter.ipynb
# Review Analysis Notebook - v1-Copy1.0.ipynb
# Review Analysis Notebook - v1.0.ipynb
# Review Process/
# Smokey Robinson.ipynb
# The "Tool".ipynb
# Tracked_Keywords - Smokey_Robinson_v1.ipynb
# Twitter_ML_Final-Copy1.ipynb
# Twitter_ML_Final.ipynb
# Untitled.ipynb
# Untitled1.ipynb
# Untitled2.ipynb
# Untitled3.ipynb
# Untitled4.ipynb
# Untitled5.ipynb
# Untitled6.ipynb
# Untitled7.ipynb
# Untitled8.ipynb
# VolumeEst-Copy1.ipynb
# VolumeEst-UK.ipynb
# VolumeEst.ipynb
# Volume_Regression_Model.pkl
# Volume_Regression_Model_High.pkl
# Volume_Regression_Model_UK.pkl
# Volume_Regression_Model_UK2.pkl
# Volume_Regression_Model_US_16-11-2019.pkl
# Volume_Regression_Model_US_2019-02-23 00:00:00.pkl
# Volume_Regression_Model_US_2019-02-23 00:00:00_udt.pkl
# Volume_Regression_Model_US_2019-03-02 00:00:00.pkl
# Volume_Regression_Model_US_2019-03-02 00:00:00_udt.pkl
# Volume_Regression_Model_US_2019-03-09 00:00:00.pkl
# Volume_Regression_Model_US_2019-03-09 00:00:00_udt.pkl
# Volume_Regression_Model_US_2019-03-16 00:00:00.pkl
# Volume_Regression_Model_US_2019-03-16 00:00:00_udt.pkl
# Volume_Regression_Model_US_2019-03-23 00:00:00.pkl
# Volume_Regression_Model_US_2019-03-23 00:00:00_udt.pkl
# Volume_Regression_Model_US_2019-03-30 00:00:00.pkl
# Volume_Regression_Model_US_2019-03-30 00:00:00_udt.pkl
# Volume_Regression_Model_US_2019-04-06 00:00:00.pkl
# Volume_Regression_Model_US_2019-04-06 00:00:00_udt.pkl
# Volume_Regression_Model_US_2019-04-13 00:00:00.pkl
# Volume_Regression_Model_US_2019-04-13 00:00:00_udt.pkl
# Volume_Regression_Model_US_2019
00:00:00_udt.pkl
# Volume_Regression_Model_US_2019-11-09.pkl
# Volume_Regression_Model_US_2019-11-16 00:00:00.pkl
# Volume_Regression_Model_US_2019-11-16 00:00:00_ud.pkl
# Volume_Regression_Model_US_2019-11-16 00:00:00_udt.pkl
# Volume_Regression_Model_US_2019-11-23 00:00:00.pkl
# Volume_Regression_Model_US_2019-11-23 00:00:00_all.pkl
# Volume_Regression_Model_US_2019-11-23 00:00:00_ud.pkl
# Volume_Regression_Model_US_2019-11-23 00:00:00_udt.pkl
# cat_rank-apptweak_scrape_and_plot.ipynb
# daily
# eBay_Impressions
# hourly
# id674258465_country-daily-report_2018-04-01_2019-09-25_PBIKULSLYUYVGQS_UTC.xlsx
# id674258465_country-daily-report_2018-04-01_2019-09-25_UCITFBNFLDTULNZ_UTC.xlsx
# photo.png
# read_from_gcp_bucket.ipynb
# smartphone_market_analysis.ipynb
# temp.png
# template_performance_charts_v2-Copy1.ipynb
# test.png
# test.txt
# wr_temp.png
#
# /Users/miguel.carvalho/dev/stuff/sandbox/warwick/Conversion_Model_data:
# accuweather-kw_sov_report-20191022.xlsx
# depop-kw_sov_report-20191022.xlsx
# ebates-kw_sov_report-20191022.xlsx
# ebay-kw_sov_report-20191022.xlsx
# hotelscom-kw_sov_report-20191022.xlsx
# priceline-kw_sov_report-20191022.xlsx
# sofi-kw_sov_report-20191022.xlsx
# stitch_fix-kw_sov_report-20191022.xlsx
#
# /Users/miguel.carvalho/dev/stuff/sandbox/warwick/Review Process:
# Model_Training_Notebook.ipynb  Review_Processing.ipynb
# Review_Categorisation.ipynb    Reviews_Graphs.ipynb
#
# /Users/miguel.carvalho/dev/stuff/scripts:
# composer_search_ads/ dags/
#
# /Users/miguel.carvalho/dev/stuff/scripts/composer_search_ads:
# live/
#
# /Users/miguel.carvalho/dev/stuff/scripts/composer_search_ads/live:
# dependencies/
#
# /Users/miguel.carvalho/dev/stuff/scripts/composer_search_ads/live/dependencies:
# __init__.py    search_ads.py
#
# /Users/miguel.carvalho/dev/stuff/scripts/dags:
# adjust-clean_adjust_raw_reports.py
# appsflyer-clean_reports.py
# appsflyer-installs_in_app_events.py
# appsflyer-installs_in_app_events_large.py
# appsflyer-installs_in_app_events_small.py
# appsflyer-pre_process_reports.py
# asa-clean_asa_reports.py
# asa-clean_asa_reports_non_clients.py
# asa-reports_data-non_clients.py
# asa-reports_data.py
# asa-static_data-non_clients.py
# asa-static_data.py
# hotels_feb_test.py
# kochava-fetch_reports.py
# kochava-pre_process_reports.py
# kochava-process_reports.py
# under_armour-merge_branch.py
#
# /Users/miguel.carvalho/dev/stuff/templates:
# ipywidgets_template_data.ipynb  tutorial-app_radar_api.ipynb
# template-gspread-Copy1.ipynb    tutorial-bigquery.ipynb
# template-gspread.ipynb          tutorial-crawl_module.ipynb
# template-new_asa_module.ipynb   tutorial_mk_process.ipynb
# template-search_ads.ipynb

# %% [markdown]
# ## Getting help with commands
#
# We can get help for a given command by preceding it with `man` (for manual).

# %%
# !man head
# Out:
# HEAD(1)                   BSD General Commands Manual                  HEAD(1)
#
# E
# d -- display first lines of a file
#
# S
# .]
#
# N
# s of each of the speci-
# t
#      is omitted it defaults to 10.
#
#      If more than a single file is specified, each file is preceded by a
#      header consisting of the string ``==> XXX <=='' where ``XXX'' is the name
#      of the file.
#
# S
# d utility exits 0 on success, and >0 if an error occurs.
#
# O
#      tail(1)
#
# Y
# d command appeared in PWB UNIX.
#
# BSD                              June 6, 1993                              BSD

# %% [markdown]
# ## How to interpret `man`?
#
# - `NAME` gives a brief explanation of what the command does
# - `SYNOPSIS` lists all the flags the command understands
# - Optionals are shown in `[...]`
# - Either/or options are separated with `|`
# - Things which can be repeated are shown by `...`

# %% [markdown]
# ## `cut`
#
# `cut` lists columns from a file. A typical usage would be:

# %%
# -f means columns and -d means the delimiter ("," in a csv)
# !cut -f 2-5,8 -d , ../../2_streamlined_data_ingestion_with_pandas/datasets/vt_tax_data_2016.csv
# Out:
# STATE,zipcode,agi_stub,N1,MARS4
# VT,0,1,111580,10740
# VT,0,2,82760,11310
# VT,0,3,46270,3620
# VT,0,4,30070,960
# VT,0,5,39530,590
# VT,0,6,9620,0
# VT,05001,1,1340,140
# VT,05001,2,1070,140
# VT,05001,3,590,70
# VT,05001,4,350,30
# VT,05001,5,450,0
# VT,05001,6,80,0
# VT,05031,1,80,0
# VT,05031,2,50,0
# VT,05031,3,50,0
# VT,05031,4,0,0
# VT,05031,5,50,0
# VT,05031,6,0,0
# VT,05032,1,410,50
# VT,05032,2,330,30
# VT,05032,3,180,20
# VT,05032,4,130,0
# VT,05032,5,110,0
# VT,05032,6,20,0
# VT,05033,1,540,60
# VT,05033,2,430,90
# VT,05033,3,230,20
# VT,05033,4,140,0
# VT,05033,5,130,0
# VT,05033,6,30,0
# VT,05034,1,80,0
# VT,05034,2,40,0
# VT,05034,3,20,0
# VT,05034,4,20,0
# VT,05034,5,30,0
# VT,05034,6,0,0
# VT,05035,1,110,0
# VT,05035,2,80,0
# VT,05035,3,60,0
# VT,05035,4,30,0
# VT,05035,5,30,0
# VT,05035,6,0,0
# VT,05036,1,130,0
# VT,05036,2,130,30
# VT,05036,3,80,0
# VT,05036,4,40,0
# VT,05036,5,70,0
# VT,05036,6,0,0
# VT,05037,1,120,0
# VT,05037,2,100,40
# VT,05037,3,70,0
# VT,05037,4,60,0
# VT,05037,5,70,0
# VT,05037,6,20,0
# VT,05038,1,250,20
# VT,05038,2,170,20
# VT,05038,3,100,0
# VT,05038,4,60,0
# VT,05038,5,80,0
# VT,05038,6,0,0
# VT,05039,1,170,30
# VT,05039,2,110,0
# VT,05039,3,60,0
# VT,05039,4,40,0
# VT,05039,5,50,0
# VT,05039,6,0,0
# VT,05040,1,120,0
# VT,05040,2,70,30
# VT,05040,3,50,0
# VT,05040,4,40,0
# VT,05040,5,30,0
# VT,05040,6,0,0
# VT,05041,1,60,0
# VT,05041,2,40,0
# VT,05041,3,20,0
# VT,05041,4,20,0
# VT,05041,5,0,0
# VT,05041,6,0,0
# VT,05042,1,100,30
# VT,05042,2,90,0
# VT,05042,3,30,0
# VT,05042,4,20,0
# VT,05042,5,40,0
# VT,05042,6,0,0
# VT,05043,1,120,0
# VT,05043,2,110,40
# VT,05043,3,60,0
# VT,05043,4,50,0
# VT,05043,5,100,0
# VT,05043,6,0,0
# VT,05857,3,100,0
# VT,05857,4,50,0
# VT,05857,5,70,0
# VT,05857,6,0,0
# VT,05858,1,80,20
# VT,05858,2,40,0
# VT,05858,3,30,0
# VT,05858,4,0,0
# VT,05858,5,0,0
# VT,05858,6,0,0
# VT,05859,1,380,50
# VT,05859,2,280,50
# VT,05859,3,100,0
# VT,05859,4,70,0
# VT,05859,5,50,0
# VT,05859,6,0,0
# VT,05860,1,510,60
# VT,05860,2,360,70
# VT,05860,3,160,0
# VT,05860,4,110,0
# VT,05860,5,70,0
# VT,05860,6,0,0
# VT,05862,1,60,0
# VT,05862,2,30,0
# VT,05862,3,30,0
# VT,05862,4,30,0
# VT,05862,5,50,0
# VT,05862,6,0,0
# VT,05866,1,130,30
# VT,05866,2,70,0
# VT,05866,3,50,0
# VT,05866,4,20,0
# VT,05866,5,20,0
# VT,05866,6,0,0
# VT,05867,1,110,30
# VT,05867,2,90,0
# VT,05867,3,50,0
# VT,05867,4,20,0
# VT,05867,5,20,0
# VT,05867,6,0,0
# VT,05868,1,60,0
# VT,05868,2,40,0
# VT,05868,3,20,0
# VT,05868,4,30,0
# VT,05868,5,0,0
# VT,05868,6,0,0
# VT,05871,1,280,30
# VT,05871,2,210,40
# VT,05871,3,110,0
# VT,05871,4,70,0
# VT,05871,5,60,0
# VT,05871,6,0,0
# VT,05872,1,170,0
# VT,05872,2,110,40
# VT,05872,3,50,0
# VT,05872,4,20,0
# VT,05872,5,20,0
# VT,05872,6,0,0
# VT,05873,1,150,20
# VT,05873,2,80,0
# VT,05873,3,60,0
# VT,05873,4,30,0
# VT,05873,5,40,0
# VT,05873,6,0,0
# VT,05874,1,140,20
# VT,05874,2,70,0
# VT,05874,3,40,0
# VT,05874,4,30,0
# VT,05874,5,30,0
# VT,05874,6,0,0
# VT,05875,1,120,0
# VT,05875,2,60,0
# VT,05875,3,40,0
# VT,05875,4,20,0
# VT,05875,5,30,0
# VT,05875,6,0,0
# VT,05903,1,160,30
# VT,05903,2,100,0
# VT,05903,3,50,0
# VT,05903,4,30,0
# VT,05903,5,40,0
# VT,05903,6,0,0
# VT,05904,1,70,0
# VT,05904,2,50,0
# VT,05904,3,0,0
# VT,05904,4,0,0
# VT,05904,5,0,0
# VT,05904,6,0,0
# VT,05905,1,140,20
# VT,05905,2,70,0
# VT,05905,3,50,0
# VT,05905,4,40,0
# VT,05905,5,30,0
# VT,05905,6,0,0
# VT,05906,1,220,20
# VT,05906,2,160,30
# VT,05906,3,60,0
# VT,05906,4,40,0
# VT,05906,5,30,0
# VT,05906,6,0,0
# VT,99999,1,2710,240
# VT,99999,2,2010,240
# VT,99999,3,1070,90
# VT,99999,4,650,30
# VT,99999,5,750,30
# VT,99999,6,180,0

# %% [markdown]
# `cut` is dumb in that it struggles with quoted strings.
#
# For instance, given the line
#
# `
# Name,Age
# "Johel,Ranjit",28
# "Sharma,Rupinder",26
# `

# %%
# !cut -f 2 -d , everyone.csv

# %% [markdown]
# would produce:
#
# `Age
# Ranjit"
# Rupinder"`

# %% [markdown]
# ## Running commands multiple times
#
# `history` shows a list of the recently run commands

# %%
# !history

# %% [markdown]
# Running `!` + command (e.g. `!head`) runs the most recent run of that command.

# %% [markdown]
# ## `grep`
#
# `grep` takes a piece of text followed by filenames and returns matches for that text in the filenames. Common flags are:
# - `-c`: print a count of the matching lines rather than the lines themselves
# - `-h`: don't print the names of the files when searching multiple files
# - `-l`: print the names of the files which match, not the matches themselves
# - `-i`: ignore case
# - `-n`: print line numbers for matching lines
# - `-v`: show lines that don't match

# %%
# all lines with the term package
# !grep -n package ../../3_software_engineering_for_data_scientists_in_python/notes/3_software_engineering_for_data_scientists_in_python.ipynb
# Out:
# 15:    "        - packages, classes and methods (in Python)\n",
# 51:      "Requirement already satisfied: pycodestyle in /Users/miguel.carvalho/.pyenv/versions/3.7.5/envs/myenv/lib/python3.7/site-packages (2.5.0)\r\n"
# 114:    "A minimal Python package consists of 2 elements: a directory and a python file. The name of the directory should be the name of the package. According to PEP8, it should be `package_name`, in a way that describes its functionality. The file in the file **must** be called `__init__.py`\n",
# 116:    "> As of Python 3.3, any directory can be imported as if it were a package without error even if it doesn't follow the structure"
# 128:    "|-- package_name\n",
# 142:      "Help on package package_name:\n",
# 145:      "    package_name\n",
# 158:    "import package_name\n",
# 161:    "help(package_name)"
# 168:    "We can add other files to our package, changing the tree to\n",
# 173:    "|-- package_name\n",
# 185:    "`import my_package.utils`"
# 202:    "import package_name.utils\n",
# 204:    "package_name.utils.we_need_to_talk(break_up=True)"
# 211:    "We can also use the package's `__init__.py` file to make our utils functions more easily accessible."
# 231:    "We can add other files to our package, changing the tree to\n",
# 236:    "|-- package_name\n",
# 248:    "We should only import the package's key functionality in the `__init__.py` file to make it directly and easily accessible."
# 255:    "We can also add subpackages to our module, making the tree look like so\n",
# 260:    "|-- package_name\n",
# 265:    "|---- sub_package\n",
# 275:    "## Making our package portable\n",
# 277:    "The two main steps to sharing a package are creating:\n",
# 286:    "|-- package_name\n",
# 293:    "|---- sub_package\n",
# 305:    "- How to recreate the environment needed to properly use your package\n",
# 306:    "    - list of python packages and (optionally) the version requirement for each package "
# 315:    "# needed packages/versions\n",
# 316:    "# 3 ways of specifying the packages and versions\n",
# 338:    "- How to install our package\n",
# 356:    "      # packages is the location of all __init__ files\n",
# 357:    "      packages=['text_analyzer'],\n",
# 358:    "      # requirements for the package to work\n",
# 402:    "## Using a class in a package"
# 412:     "evalue": "module 'package_name' has no attribute 'MyClass'",
# 417:      "\u001b<ipython-input-2-aa22356fc660>\u001b in \u001b<module>\u001b\u001b\n\u001b      1\u001b \u001bimport\u001b \u001bpackage_name\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b      2\u001b \u001b\u001b\u001b\n\u001b----> 3\u001b \u001bmy_instance\u001b \u001b=\u001b \u001bpackage_name\u001b\u001b.\u001b\u001bMyClass\u001b\u001b(\u001b\u001b)\u001b\u001b\u001b\u001b\u001b\u001b\n\u001b",
# 418:      "\u001bAttributeError\u001b: module 'package_name' has no attribute 'MyClass'"
# 423:    "import package_name\n",
# 425:    "my_instance = package_name.MyClass()"

# %% [markdown]
# ## Combining Tools

# %% [markdown]
# # Putting Files in the Cloud
#
# Typical projects will need the following to be successful:
# - storage
# - computer services
# - notifications

# %% [markdown]
# ## Boto3
#
# `boto3` is used to intereact with AWS in python.

# %%
# !pip install boto3
# http://2017.compciv.org/guide/topics/aws/intro-to-aws-boto3.html#id4 - worth checking

# %%
import boto3

s3 = boto3.client(
    's3',
#     region_name="us-east-1",
#     aws_access_key_id=os.environ.get(AWS_KEY_ID),
#     aws_secret_access_key=os.environ.get(AWS_SECRET),
)

response = s3.list_buckets()

# %% [markdown]
# ## Initial set-up
#
# 1. Create a key and a secret for `boto3` through IAM services
# 2. `pip install awscli`
#     - http://2017.compciv.org/guide/topics/aws/intro-to-aws-boto3.html#id4

# %% [markdown]
# ## Some AWS services
#
# - IAM
# - S3
# - SNS
# - Comprehend
# - Rekognition

# %% [markdown]
# ## Creating multiple clients
#
# We can create multiple `boto3` clients from the script

# %%
# Generate the boto3 client for interacting with S3 and SNS
s3 = boto3.client('s3', region_name="us-east-1")

sns = boto3.client('sns', region_name="us-east-1")

# List S3 buckets and SNS topics
buckets = s3.list_buckets()
topics = sns.list_topics()

# Print out the list of SNS topics
print(topics)
# Out:
# {'Topics': [], 'ResponseMetadata': {'RequestId': '505dbd5a-6885-556b-bcc4-ebe5e0c873a1', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '505dbd5a-6885-556b-bcc4-ebe5e0c873a1', 'content-type': 'text/xml', 'content-length': '256', 'date': 'Thu, 13 Feb 2020 17:23:25 GMT'}, 'RetryAttempts': 0}}

# %% [markdown]
# ## Diving into buckets
#
# With S3 we can put any file in the cloud and make accessible anywhere via a URL.
#
# S3 consists of:
# - buckets
#     - similar to folders in a desktop
#     - own permission policies
#     - can be configured to act as folders to a website (website storage)
#     - generate logs
#     - most importantly: buckets contain objects (objects can be anything!)
# - objects
#     - similar to files in folders\
#
# ### Using buckets in `boto3`
#
# We can:
# - create a bucket
# - list buckets
# - delete a bucket
#
# #### Creating a bucket

# %%
import boto3

s3 = boto3.client("s3") # rest is configured in awscli

# %%
bucket = s3.create_bucket(Bucket="miguel-gid-requests")

# %% [markdown]
# #### Creating a bucket

# %%
s3.list_buckets()["Buckets"]
# Out:
# [{'Name': 'dned-miguelccarvalho-bucket-demo', 'CreationDate': datetime.datetime(2019, 8, 27, 8, 54, 35, tzinfo=tzutc())}, {'Name': 'miguel-gid-requests', 'CreationDate': datetime.datetime(2020, 2, 13, 13, 56, 26, tzinfo=tzutc())}]

# %% [markdown]
# #### Deleting a bucket

# %%
s3.delete_bucket(Bucket="miguel-gid-requests")
# Out:
# {'ResponseMetadata': {'RequestId': '9DE8933C0C7AD6A0', 'HostId': 'l8cHKfOd7CJnzyijh8cKOYwU+mQwCLUWukOft4vp8udbfhjbuGlW4mS0erH9/7Ye6aonCCSWmPI=', 'HTTPStatusCode': 204, 'HTTPHeaders': {'x-amz-id-2': 'l8cHKfOd7CJnzyijh8cKOYwU+mQwCLUWukOft4vp8udbfhjbuGlW4mS0erH9/7Ye6aonCCSWmPI=', 'x-amz-request-id': '9DE8933C0C7AD6A0', 'date': 'Thu, 13 Feb 2020 13:59:35 GMT', 'server': 'AmazonS3'}, 'RetryAttempts': 0}}

# %%
s3.list_buckets()["Buckets"]
# Out:
# [{'Name': 'dned-miguelccarvalho-bucket-demo', 'CreationDate': datetime.datetime(2019, 8, 27, 8, 54, 35, tzinfo=tzutc())}]

# %% [markdown]
# ## Uploading and retrieving files
#
# Files in S3 buckets are called *objects*. These objects can be anything: `.csv`, `.pdf`, `.mp4`, etc.
#
# ### Bucket vs Objects
#
# Bucket:
# - has a name
# - name is a string
# - unique name in all of S3
# - contains many objects
#
# Object:
# - object has a key
# - name in full path from bucket root
# - unique key in the bucket
# - can be only in one parent bucket

# %%
# check available buckets before uploading
s3.list_buckets()["Buckets"]
# Out:
# [{'Name': 'dned-miguelccarvalho-bucket-demo', 'CreationDate': datetime.datetime(2019, 8, 27, 8, 54, 35, tzinfo=tzutc())}]

# %%
# notice it does not return anything
# in case of an error, an exception is thrown
s3.upload_file(
    Filename="../../5_introduction_to_shell/datasets/cities.csv", # local filename
    Bucket="dned-miguelccarvalho-bucket-demo", # bucket to be parent of file
    Key="cities.csv" # s3 name for thee file
)

# %%
# listing objects
s3.list_objects(
    Bucket="dned-miguelccarvalho-bucket-demo",
    MaxKeys=2, # limiting max results to 2, if ommitted, default is 1000
    Prefix="cit" # only objects which prefix match this string
)
# Out:
# {'ResponseMetadata': {'RequestId': 'BB7B701CE90A552A', 'HostId': 'tDXhv5NtBXwUmI/erMV/eclAWF8bq5UTzLJL+AF3xOeNyELNc6O1JgzRQEVI6GddnckrpOQh8mM=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'tDXhv5NtBXwUmI/erMV/eclAWF8bq5UTzLJL+AF3xOeNyELNc6O1JgzRQEVI6GddnckrpOQh8mM=', 'x-amz-request-id': 'BB7B701CE90A552A', 'date': 'Thu, 13 Feb 2020 14:11:45 GMT', 'x-amz-bucket-region': 'eu-west-2', 'content-type': 'application/xml', 'transfer-encoding': 'chunked', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'IsTruncated': False, 'Marker': '', 'Contents': [{'Key': 'cities.csv', 'LastModified': datetime.datetime(2020, 2, 13, 14, 10, 1, tzinfo=tzutc()), 'ETag': '"2dd39cb6de5ecc471fa37f1f2aac759f"', 'Size': 8402, 'StorageClass': 'STANDARD', 'Owner': {'ID': 'e6119f625207062af5bb798a6418c2872efd1a107133fdb9f3c3580b850f313b'}}], 'Name': 'dned-miguelccarvalho-bucket-demo', 'Prefix': 'cit', 'MaxKeys': 2, 'EncodingType': 'url'}

# %%
# listing objects
s3.list_objects(
    Bucket="dned-miguelccarvalho-bucket-demo",
    MaxKeys=2, # limiting max results to 2, if ommitted, default is 1000
    Prefix="cit" # only objects which prefix match this string
)["Contents"]
# Out:
# [{'Key': 'cities.csv', 'LastModified': datetime.datetime(2020, 2, 13, 14, 10, 1, tzinfo=tzutc()), 'ETag': '"2dd39cb6de5ecc471fa37f1f2aac759f"', 'Size': 8402, 'StorageClass': 'STANDARD', 'Owner': {'ID': 'e6119f625207062af5bb798a6418c2872efd1a107133fdb9f3c3580b850f313b'}}]

# %%
# downloading a file
s3.download_file(
    Filename="cities.csv", # filename and local path to be downloaded to
    Bucket="dned-miguelccarvalho-bucket-demo",
    Key="cities.csv"
)

# %%
# !ls
# Out:
# 8_introduction_to_aws_boto_in_python.ipynb
# cities.csv

# %%
# deleting a file
s3.delete_object(
    Bucket="dned-miguelccarvalho-bucket-demo",
    Key="cities.csv"
)
# Out:
# {'ResponseMetadata': {'RequestId': '2160F59BC8457FF9', 'HostId': 'IVIgOeJ27RxdxbGkG3dWM/Xq81Cv0jbqIT6xlCU4LlUwFNJ42ImpYb8v3U6XhTzpsn03xZEgU7E=', 'HTTPStatusCode': 204, 'HTTPHeaders': {'x-amz-id-2': 'IVIgOeJ27RxdxbGkG3dWM/Xq81Cv0jbqIT6xlCU4LlUwFNJ42ImpYb8v3U6XhTzpsn03xZEgU7E=', 'x-amz-request-id': '2160F59BC8457FF9', 'date': 'Thu, 13 Feb 2020 14:15:06 GMT', 'server': 'AmazonS3'}, 'RetryAttempts': 0}}

# %%
# listing objects
# see there is no Contents key
response = s3.list_objects(
    Bucket="dned-miguelccarvalho-bucket-demo",
    MaxKeys=2, # limiting max results to 2, if ommitted, default is 1000
    Prefix="cit" # only objects which prefix match this string
)

# %%
if 'Contents' in response:
    for obj in response["Contents"]:
        print(obj["Name"])

# %% [markdown]
# > Add `if 'Contents' in response:` in case no responses are returned otherwise we'll get a `KeyError`

# %% [markdown]
# # Sharing Files Securely
#
# The default for files is to deny permission - files are only accessible with our key.

# %% [markdown]
# ## AWS Permissions Systems
#
# There are 4 ways to control permission is S3:
#
# 1. IAM (what can the user do in AWS?)
#     - Use this to control users' access to services, buckets, objects
#     - We attach IAM policies to a user
#     - Applies across all AWS Services
# 2. Bucket Policy (who can access this S3 bucket?)
#     - Gives us control of the bucket and the objects within it
# 3. ACL (who can access object?)
#     - Let us set permissions on specific objects within a bucket
# 4. Presigned URL
#     - Let us provide temporary access to an object
#
# IAM and Bucket Policies are great in multi-user environments.

# %% [markdown]
# ## ACL
#
# ACLs are entities attached  to objects in S3. We will focus on two types of ACL:
# 1. Private
# 2. Public read
#
# By default ACL is private. We can change it to public.

# %%
# let's upload this file again
s3.upload_file(
    Filename="../../5_introduction_to_shell/datasets/cities.csv", # local filename
    Bucket="dned-miguelccarvalho-bucket-demo", # bucket to be parent of file
    Key="cities.csv" # s3 name for thee file
)

# %%
s3.put_object_acl(
    Bucket="dned-miguelccarvalho-bucket-demo",
    Key="cities.csv",
    ACL="public-read"
)
# Out:
# {'ResponseMetadata': {'RequestId': '1F880108F0754C75', 'HostId': '7iJ1hHWcnN2zs8bPfTEIbbl1SYBfh3rOMFYcihkHO/eHkDfkydz82wcpCtRalcS3kIgtwwHiDIY=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': '7iJ1hHWcnN2zs8bPfTEIbbl1SYBfh3rOMFYcihkHO/eHkDfkydz82wcpCtRalcS3kIgtwwHiDIY=', 'x-amz-request-id': '1F880108F0754C75', 'date': 'Thu, 13 Feb 2020 14:28:40 GMT', 'content-length': '0', 'server': 'AmazonS3'}, 'RetryAttempts': 0}}

# %%
# we can also do this on upload
# let's upload this file again
s3.upload_file(
    Filename="../../5_introduction_to_shell/datasets/cities.csv", # local filename
    Bucket="dned-miguelccarvalho-bucket-demo", # bucket to be parent of file
    Key="cities_2.csv", # s3 name for thee file
    ExtraArgs={"ACL":"public-read"} 
)

# %% [markdown]
# ### Accessing public objects
#
# If an object is public, anyone can access it with:
#
# https://{bucket}.s3.{region}.amazonaws.com/{key}

# %% [markdown]
# https://dned-miguelccarvalho-bucket-demo.s3.eu-west-2.amazonaws.com/cities_2.csv

# %%
url = "https://dned-miguelccarvalho-bucket-demo.s3.eu-west-2.amazonaws.com/cities_2.csv"
pd.read_csv(url)
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      46       35       59   "N"      120       30       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# 5      36        5       59   "N"       80       15        0   "W"
# 6      49       52       48   "N"       97        9        0   "W"
# 7      39       11       23   "N"       78        9       36   "W"
# 8      34       14       24   "N"       77       55       11   "W"
# 9      39       45        0   "N"       75       33        0   "W"
# 10     48        9        0   "N"      103       37       12   "W"
# 11     41       15        0   "N"       77        0        0   "W"
# 12     37       40       48   "N"       82       16       47   "W"
# 13     33       54        0   "N"       98       29       23   "W"
# 14     37       41       23   "N"       97       20       23   "W"
# 15     40        4       11   "N"       80       43       12   "W"
# 16     26       43       11   "N"       80        3        0   "W"
# 17     47       25       11   "N"      120       19       11   "W"
# 18     41       25       11   "N"      122       23       23   "W"
# 19     31       13       11   "N"       82       20       59   "W"
# 20     44       57       35   "N"       89       38       23   "W"
# 21     42       21       36   "N"       87       49       48   "W"
# 22     44       54        0   "N"       97        6       36   "W"
# 23     43       58       47   "N"       75       55       11   "W"
# 24     42       30        0   "N"       92       20       23   "W"
# 25     41       32       59   "N"       73        3        0   "W"
# 26     38       53       23   "N"       77        1       47   "W"
# 27     41       50       59   "N"       79        8       23   "W"
# 28     46        4       11   "N"      118       19       48   "W"
# 29     31       32       59   "N"       97        8       23   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 98     36       40       11   "N"      121       39        0   "W"
# 99     38       50       24   "N"       97       36       36   "W"
# 100    38       31       47   "N"      106        0        0   "W"
# 101    44       56       23   "N"      123        1       47   "W"
# 102    44       57        0   "N"       93        5       59   "W"
# 103    38       37       11   "N"       90       11       24   "W"
# 104    39       46       12   "N"       94       50       23   "W"
# 105    42        5       59   "N"       86       28       48   "W"
# 106    44       25       11   "N"       72        1       11   "W"
# 107    45       34       11   "N"       94       10       11   "W"
# 108    29       53       23   "N"       81       19       11   "W"
# 109    43       25       48   "N"       83       56       24   "W"
# 110    38       35       24   "N"      121       29       23   "W"
# 111    43       36       36   "N"       72       58       12   "W"
# 112    33       24        0   "N"      104       31       47   "W"
# 113    35       56       23   "N"       77       48        0   "W"
# 114    41       35       24   "N"      109       13       48   "W"
# 115    42       16       12   "N"       89        5       59   "W"
# 116    43        9       35   "N"       77       36       36   "W"
# 117    44        1       12   "N"       92       27       35   "W"
# 118    37       16       12   "N"       79       56       24   "W"
# 119    37       32       24   "N"       77       26       59   "W"
# 120    39       49       48   "N"       84       53       23   "W"
# 121    38       46       12   "N"      112        5       23   "W"
# 122    45       38       23   "N"       89       25       11   "W"
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# 1             "Yankton"       SD
# 2              "Yakima"       WA
# 3           "Worcester"       MA
# 4     "Wisconsin Dells"       WI
# 5       "Winston-Salem"       NC
# 6            "Winnipeg"       MB
# 7          "Winchester"       VA
# 8          "Wilmington"       NC
# 9          "Wilmington"       DE
# 10          "Williston"       ND
# 11       "Williamsport"       PA
# 12         "Williamson"       WV
# 13      "Wichita Falls"       TX
# 14            "Wichita"       KS
# 15           "Wheeling"       WV
# 16    "West Palm Beach"       FL
# 17          "Wenatchee"       WA
# 18               "Weed"       CA
# 19           "Waycross"       GA
# 20             "Wausau"       WI
# 21           "Waukegan"       IL
# 22          "Watertown"       SD
# 23          "Watertown"       NY
# 24           "Waterloo"       IA
# 25          "Waterbury"       CT
# 26         "Washington"       DC
# 27             "Warren"       PA
# 28        "Walla Walla"       WA
# 29               "Waco"       TX
# ..                  ...      ...
# 98            "Salinas"       CA
# 99             "Salina"       KS
# 100            "Salida"       CO
# 101             "Salem"       OR
# 102        "Saint Paul"       MN
# 103       "Saint Louis"       MO
# 104      "Saint Joseph"       MO
# 105      "Saint Joseph"       MI
# 106   "Saint Johnsbury"       VT
# 107       "Saint Cloud"       MN
# 108   "Saint Augustine"       FL
# 109           "Saginaw"       MI
# 110        "Sacramento"       CA
# 111           "Rutland"       VT
# 112           "Roswell"       NM
# 113       "Rocky Mount"       NC
# 114      "Rock Springs"       WY
# 115          "Rockford"       IL
# 116         "Rochester"       NY
# 117         "Rochester"       MN
# 118           "Roanoke"       VA
# 119          "Richmond"       VA
# 120          "Richmond"       IN
# 121         "Richfield"       UT
# 122       "Rhinelander"       WI
# 123              "Reno"       NV
# 124            "Regina"       SA
# 125         "Red Bluff"       CA
# 126           "Reading"       PA
# 127           "Ravenna"      OH
#
# [128 rows x 10 columns]

# %% [markdown]
# ### How access is decided
#
# 1. Someone requests a download
# 2. Check for pre-signed URL: if ok, allow; if not, check policies
# 3. Check IAM, Bucket Policy, and ACL: if ok, allow; if not, deny

# %% [markdown]
# ## Accessing private objects in S3
#
# Since by default access is forbidden, we won't be able to read files with pandas.

# %%
private_url = "https://dned-miguelccarvalho-bucket-demo.s3.eu-west-2.amazonaws.com/2018-11-28-events.json"

# check how we get a 403 error
pd.read_csv(private_url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-70-1ae1836064fa> in <module>
#       2
#       3 # check how we get a 403 error
# ----> 4 pd.read_csv(private_url)
#
# ~/.pyenv/versions/3.7.5/envs/myenv/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/.pyenv/versions/3.7.5/envs/myenv/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     411     compression = _infer_compression(filepath_or_buffer, compression)
#     412     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(
# --> 413         filepath_or_buffer, encoding, compression)
#     414     kwds['compression'] = compression
#     415
#
# ~/.pyenv/versions/3.7.5/envs/myenv/lib/python3.7/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#     200
#     201     if _is_url(filepath_or_buffer):
# --> 202         req = _urlopen(filepath_or_buffer)
#     203         content_encoding = req.headers.get('Content-Encoding', None)
#     204         if content_encoding == 'gzip':
#
# ~/.pyenv/versions/3.7.5/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/.pyenv/versions/3.7.5/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/.pyenv/versions/3.7.5/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~/.pyenv/versions/3.7.5/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~/.pyenv/versions/3.7.5/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/.pyenv/versions/3.7.5/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %% [markdown]
# ### Solutions
#
# If the file is not expected to change much:
#
# 1. Download the file with `s3.download_file`
# 2. Use `pd.read_csv` with file locally saved
#
# Better option:

# %%
obj = s3.get_object(
    Bucket="dned-miguelccarvalho-bucket-demo",
    Key="2018-11-28-events.json"
)

print(obj)
# Out:
# {'ResponseMetadata': {'RequestId': '219D6B315D2DD587', 'HostId': '2PEZjCO/h7myVEXbzn6QSCrYSDJxQJ01lQNagEqoQoKQBGi0C5JixB0RHwMGsrGqZ7MSoviECfE=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': '2PEZjCO/h7myVEXbzn6QSCrYSDJxQJ01lQNagEqoQoKQBGi0C5JixB0RHwMGsrGqZ7MSoviECfE=', 'x-amz-request-id': '219D6B315D2DD587', 'date': 'Thu, 13 Feb 2020 14:57:00 GMT', 'last-modified': 'Tue, 27 Aug 2019 08:57:01 GMT', 'etag': '"958bb973e883807f00a35801b9191c7f"', 'accept-ranges': 'bytes', 'content-type': 'application/json', 'content-length': '202910', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'AcceptRanges': 'bytes', 'LastModified': datetime.datetime(2019, 8, 27, 8, 57, 1, tzinfo=tzutc()), 'ContentLength': 202910, 'ETag': '"958bb973e883807f00a35801b9191c7f"', 'ContentType': 'application/json', 'Metadata': {}, 'Body': <botocore.response.StreamingBody object at 0x11c432090>}

# %%
# we get a streaming body as part of the response's body key
# pandas can read this!
pd.read_csv(obj["Body"])
# Out:
#           {"artist":"Mitch Ryder & The Detroit Wheels"   auth:"Logged In"  \
# 0                         {"artist":"The Spill Canvas"   auth:"Logged In"
# 1                                   {"artist":"Mogwai"   auth:"Logged In"
# 2                                     {"artist":"Spor"   auth:"Logged In"
# 3                                 {"artist":"DJ Dizzy"   auth:"Logged In"
# 4                              {"artist":"Erik Hassle"   auth:"Logged In"
# 5                                       {"artist":null  auth:"Logged Out"
# 6                                       {"artist":null  auth:"Logged Out"
# 7                                       {"artist":null   auth:"Logged In"
# 8                                       {"artist":null   auth:"Logged In"
# 9                                       {"artist":null   auth:"Logged In"
# 10                                      {"artist":null  auth:"Logged Out"
# 11                                      {"artist":null   auth:"Logged In"
# 12                                 {"artist":"Phoenix"   auth:"Logged In"
# 13                          {"artist":"Arctic Monkeys"   auth:"Logged In"
# 14                                 {"artist":"tobyMac"   auth:"Logged In"
# 15                                      {"artist":null   auth:"Logged In"
# 16   {"artist":"Jadakiss \/ Swizz Beatz \/ OJ Da Ju...   auth:"Logged In"
# 17                  {"artist":"Florence + The Machine"   auth:"Logged In"
# 18                       {"artist":"The White Stripes"   auth:"Logged In"
# 19                                {"artist":"Plus One"   auth:"Logged In"
# 20                          {"artist":"Counting Crows"   auth:"Logged In"
# 21                       {"artist":"Pickin' On Series"   auth:"Logged In"
# 22                                  {"artist":"Eminem"   auth:"Logged In"
# 23                                   {"artist":"Heart"   auth:"Logged In"
# 24                                      {"artist":null   auth:"Logged In"
# 25                                      {"artist":null  auth:"Logged Out"
# 26                                      {"artist":null  auth:"Logged Out"
# 27                                      {"artist":null   auth:"Logged In"
# 28                            {"artist":"Sergio Dalma"   auth:"Logged In"
# 29                                     {"artist":"AFI"   auth:"Logged In"
# ..                                                 ...                ...
# 402                               {"artist":"Gorillaz"   auth:"Logged In"
# 403                            {"artist":"Silverstein"   auth:"Logged In"
# 404                                {"artist":"Example"   auth:"Logged In"
# 405                           {"artist":"Shania Twain"   auth:"Logged In"
# 406                               {"artist":"Skindred"   auth:"Logged In"
# 407                                     {"artist":null   auth:"Logged In"
# 408                             {"artist":"Kanye West"   auth:"Logged In"
# 409                             {"artist":"Aloe Blacc"   auth:"Logged In"
# 410                                 {"artist":"Common"   auth:"Logged In"
# 411                        {"artist":"The Belle Stars"   auth:"Logged In"
# 412                                  {"artist":"Feist"   auth:"Logged In"
# 413                            {"artist":"Lupe Fiasco"   auth:"Logged In"
# 414                           {"artist":"Natalie Cole"   auth:"Logged In"
# 415                                {"artist":"Placebo"   auth:"Logged In"
# 416                                   {"artist":"2Mex"   auth:"Logged In"
# 417                            {"artist":"Brother Ali"   auth:"Logged In"
# 418                              {"artist":"Meat Loaf"   auth:"Logged In"
# 419                                {"artist":"MC Lars"   auth:"Logged In"
# 420         {"artist":"Beyonc\u00c3\u0083\u00c2\u00a9"   auth:"Logged In"
# 421                           {"artist":"Joy Division"   auth:"Logged In"
# 422                         {"artist":"Dierks Bentley"   auth:"Logged In"
# 423                                     {"artist":null  auth:"Logged Out"
# 424                       {"artist":"Devendra Banhart"   auth:"Logged In"
# 425                         {"artist":"Camera Obscura"   auth:"Logged In"
# 426                                {"artist":"Prodigy"   auth:"Logged In"
# 427                               {"artist":"Aventura"   auth:"Logged In"
# 428                              {"artist":"Die Sekte"   auth:"Logged In"
# 429                           {"artist":"Kid Dynamite"   auth:"Logged In"
# 430                      {"artist":"Eminem \/ Bizarre"   auth:"Logged In"
# 431                  {"artist":"Explosions In The Sky"   auth:"Logged In"
#
#       firstName:"Tegan"   gender:"F"  itemInSession:65    lastName:"Levine"  \
# 0     firstName:"Tegan"   gender:"F"  itemInSession:66    lastName:"Levine"
# 1     firstName:"Tegan"   gender:"F"  itemInSession:67    lastName:"Levine"
# 2     firstName:"Tegan"   gender:"F"  itemInSession:68    lastName:"Levine"
# 3     firstName:"Tegan"   gender:"F"  itemInSession:69    lastName:"Levine"
# 4     firstName:"Tegan"   gender:"F"  itemInSession:70    lastName:"Levine"
# 5        firstName:null  gender:null   itemInSession:0        lastName:null
# 6        firstName:null  gender:null   itemInSession:1        lastName:null
# 7    firstName:"Aleena"   gender:"F"   itemInSession:2     lastName:"Kirby"
# 8     firstName:"Tegan"   gender:"F"  itemInSession:71    lastName:"Levine"
# 9    firstName:"Sylvie"   gender:"F"   itemInSession:0      lastName:"Cruz"
# 10       firstName:null  gender:null   itemInSession:0        lastName:null
# 11    firstName:"Ryann"   gender:"F"   itemInSession:1     lastName:"Smith"
# 12    firstName:"Ryann"   gender:"F"   itemInSession:2     lastName:"Smith"
# 13    firstName:"Ryann"   gender:"F"   itemInSession:3     lastName:"Smith"
# 14   firstName:"Braden"   gender:"M"   itemInSession:0    lastName:"Parker"
# 15   firstName:"Martin"   gender:"M"   itemInSession:0   lastName:"Johnson"
# 16   firstName:"Martin"   gender:"M"   itemInSession:1   lastName:"Johnson"
# 17   firstName:"Tucker"   gender:"M"   itemInSession:0  lastName:"Garrison"
# 18   firstName:"Tucker"   gender:"M"   itemInSession:1  lastName:"Garrison"
# 19    firstName:"Emily"   gender:"F"   itemInSession:0    lastName:"Benson"
# 20    firstName:"Emily"   gender:"F"   itemInSession:1    lastName:"Benson"
# 21    firstName:"Wyatt"   gender:"M"   itemInSession:0     lastName:"Scott"
# 22    firstName:"Emily"   gender:"F"   itemInSession:2    lastName:"Benson"
# 23    firstName:"Wyatt"   gender:"M"   itemInSession:1     lastName:"Scott"
# 24    firstName:"Wyatt"   gender:"M"   itemInSession:2     lastName:"Scott"
# 25       firstName:null  gender:null   itemInSession:3        lastName:null
# 26       firstName:null  gender:null   itemInSession:4        lastName:null
# 27    firstName:"Wyatt"   gender:"M"   itemInSession:5     lastName:"Scott"
# 28    firstName:"Emily"   gender:"F"   itemInSession:3    lastName:"Benson"
# 29    firstName:"Wyatt"   gender:"M"   itemInSession:6     lastName:"Scott"
# ..                  ...          ...               ...                  ...
# 402   firstName:"Jacob"   gender:"M"  itemInSession:39     lastName:"Klein"
# 403   firstName:"Layla"   gender:"F"  itemInSession:73   lastName:"Griffin"
# 404   firstName:"Jacob"   gender:"M"  itemInSession:40     lastName:"Klein"
# 405   firstName:"Jacob"   gender:"M"  itemInSession:41     lastName:"Klein"
# 406   firstName:"Layla"   gender:"F"  itemInSession:74   lastName:"Griffin"
# 407   firstName:"Layla"   gender:"F"  itemInSession:75   lastName:"Griffin"
# 408   firstName:"Jacob"   gender:"M"  itemInSession:42     lastName:"Klein"
# 409   firstName:"Layla"   gender:"F"  itemInSession:76   lastName:"Griffin"
# 410   firstName:"Jacob"   gender:"M"  itemInSession:43     lastName:"Klein"
# 411   firstName:"Layla"   gender:"F"  itemInSession:77   lastName:"Griffin"
# 412   firstName:"Jacob"   gender:"M"  itemInSession:44     lastName:"Klein"
# 413   firstName:"Layla"   gender:"F"  itemInSession:78   lastName:"Griffin"
# 414   firstName:"Jacob"   gender:"M"  itemInSession:45     lastName:"Klein"
# 415   firstName:"Layla"   gender:"F"  itemInSession:79   lastName:"Griffin"
# 416   firstName:"Jacob"   gender:"M"  itemInSession:46     lastName:"Klein"
# 417   firstName:"Layla"   gender:"F"  itemInSession:80   lastName:"Griffin"
# 418   firstName:"Jacob"   gender:"M"  itemInSession:47     lastName:"Klein"
# 419   firstName:"Layla"   gender:"F"  itemInSession:81   lastName:"Griffin"
# 420   firstName:"Layla"   gender:"F"  itemInSession:82   lastName:"Griffin"
# 421   firstName:"Layla"   gender:"F"  itemInSession:83   lastName:"Griffin"
# 422   firstName:"Jacob"   gender:"M"  itemInSession:48     lastName:"Klein"
# 423      firstName:null  gender:null   itemInSession:0        lastName:null
# 424   firstName:"Layla"   gender:"F"  itemInSession:84   lastName:"Griffin"
# 425   firstName:"Jacob"   gender:"M"  itemInSession:49     lastName:"Klein"
# 426   firstName:"Layla"   gender:"F"  itemInSession:85   lastName:"Griffin"
# 427   firstName:"Jacob"   gender:"M"  itemInSession:50     lastName:"Klein"
# 428   firstName:"Layla"   gender:"F"  itemInSession:86   lastName:"Griffin"
# 429   firstName:"Jacob"   gender:"M"  itemInSession:51     lastName:"Klein"
# 430   firstName:"Jacob"   gender:"M"  itemInSession:52     lastName:"Klein"
# 431   firstName:"Layla"   gender:"F"  itemInSession:87   lastName:"Griffin"
#
#      length:205.03465  level:"paid"  \
# 0    length:358.03383  level:"paid"
# 1    length:571.19302  level:"paid"
# 2     length:380.3424  level:"paid"
# 3     length:221.1522  level:"paid"
# 4    length:183.43138  level:"paid"
# 5         length:null  level:"paid"
# 6         length:null  level:"paid"
# 7         length:null  level:"paid"
# 8         length:null  level:"paid"
# 9         length:null  level:"free"
# 10        length:null  level:"free"
# 11        length:null  level:"free"
# 12   length:207.15057  level:"free"
# 13   length:175.43791  level:"free"
# 14   length:229.69424  level:"free"
# 15        length:null  level:"free"
# 16   length:191.84281  level:"free"
# 17   length:219.66322  level:"free"
# 18   length:160.31302  level:"free"
# 19    length:231.8624  level:"paid"
# 20   length:272.79628  level:"paid"
# 21   length:199.41832  level:"free"
# 22   length:320.83546  level:"paid"
# 23   length:270.18404  level:"free"
# 24        length:null  level:"free"
# 25        length:null  level:"free"
# 26        length:null  level:"free"
# 27        length:null  level:"free"
# 28   length:269.45261  level:"paid"
# 29   length:256.86159  level:"free"
# ..                ...           ...
# 402  length:227.05587  level:"paid"
# 403  length:222.79791  level:"paid"
# 404   length:180.4273  level:"paid"
# 405  length:198.32118  level:"paid"
# 406    length:238.602  level:"paid"
# 407       length:null  level:"paid"
# 408  length:196.77995  level:"paid"
# 409   length:244.1922  level:"paid"
# 410  length:224.13016  level:"paid"
# 411  length:178.85995  level:"paid"
# 412   length:223.7122  level:"paid"
# 413  length:312.92036  level:"paid"
# 414  length:188.57751  level:"paid"
# 415  length:190.61506  level:"paid"
# 416  length:243.06893  level:"paid"
# 417  length:204.53832  level:"paid"
# 418  length:597.86404  level:"paid"
# 419  length:222.87628  level:"paid"
# 420  length:236.35546  level:"paid"
# 421  length:254.09261  level:"paid"
# 422  length:239.12444  level:"paid"
# 423       length:null  level:"paid"
# 424  length:134.76526  level:"paid"
# 425  length:207.01995  level:"paid"
# 426  length:335.90812  level:"paid"
# 427  length:278.04689  level:"paid"
# 428  length:206.18404  level:"paid"
# 429  length:119.95383  level:"paid"
# 430  length:244.55791  level:"paid"
# 431   length:220.3424  level:"paid"
#
#               location:"Portland-South Portland            ME"  method:"PUT"  \
# 0             location:"Portland-South Portland            ME"  method:"PUT"
# 1             location:"Portland-South Portland            ME"  method:"PUT"
# 2             location:"Portland-South Portland            ME"  method:"PUT"
# 3             location:"Portland-South Portland            ME"  method:"PUT"
# 4             location:"Portland-South Portland            ME"  method:"PUT"
# 5                                 location:null   method:"GET"   page:"Home"
# 6                                 location:null   method:"PUT"  page:"Login"
# 7                location:"Waterloo-Cedar Falls            IA"  method:"GET"
# 8             location:"Portland-South Portland            ME"  method:"GET"
# 9     location:"Washington-Arlington-Alexandria   DC-VA-MD-WV"  method:"GET"
# 10                                location:null   method:"PUT"  page:"Login"
# 11                          location:"Palestine            TX"  method:"GET"
# 12                          location:"Palestine            TX"  method:"PUT"
# 13                          location:"Palestine            TX"  method:"PUT"
# 14         location:"Youngstown-Warren-Boardman         OH-PA"  method:"PUT"
# 15   location:"Minneapolis-St. Paul-Bloomington         MN-WI"  method:"GET"
# 16   location:"Minneapolis-St. Paul-Bloomington         MN-WI"  method:"PUT"
# 17       location:"Oxnard-Thousand Oaks-Ventura            CA"  method:"PUT"
# 18       location:"Oxnard-Thousand Oaks-Ventura            CA"  method:"PUT"
# 19            location:"Augusta-Richmond County         GA-SC"  method:"PUT"
# 20            location:"Augusta-Richmond County         GA-SC"  method:"PUT"
# 21              location:"Eureka-Arcata-Fortuna            CA"  method:"PUT"
# 22            location:"Augusta-Richmond County         GA-SC"  method:"PUT"
# 23              location:"Eureka-Arcata-Fortuna            CA"  method:"PUT"
# 24              location:"Eureka-Arcata-Fortuna            CA"  method:"PUT"
# 25                                location:null   method:"GET"   page:"Home"
# 26                                location:null   method:"PUT"  page:"Login"
# 27              location:"Eureka-Arcata-Fortuna            CA"  method:"GET"
# 28            location:"Augusta-Richmond County         GA-SC"  method:"PUT"
# 29              location:"Eureka-Arcata-Fortuna            CA"  method:"PUT"
# ..                                          ...            ...           ...
# 402   location:"Tampa-St. Petersburg-Clearwater            FL"  method:"PUT"
# 403          location:"Lake Havasu City-Kingman            AZ"  method:"PUT"
# 404   location:"Tampa-St. Petersburg-Clearwater            FL"  method:"PUT"
# 405   location:"Tampa-St. Petersburg-Clearwater            FL"  method:"PUT"
# 406          location:"Lake Havasu City-Kingman            AZ"  method:"PUT"
# 407          location:"Lake Havasu City-Kingman            AZ"  method:"GET"
# 408   location:"Tampa-St. Petersburg-Clearwater            FL"  method:"PUT"
# 409          location:"Lake Havasu City-Kingman            AZ"  method:"PUT"
# 410   location:"Tampa-St. Petersburg-Clearwater            FL"  method:"PUT"
# 411          location:"Lake Havasu City-Kingman            AZ"  method:"PUT"
# 412   location:"Tampa-St. Petersburg-Clearwater            FL"  method:"PUT"
# 413          location:"Lake Havasu City-Kingman            AZ"  method:"PUT"
# 414   location:"Tampa-St. Petersburg-Clearwater            FL"  method:"PUT"
# 415          location:"Lake Havasu City-Kingman            AZ"  method:"PUT"
# 416   location:"Tampa-St. Petersburg-Clearwater            FL"  method:"PUT"
# 417          location:"Lake Havasu City-Kingman            AZ"  method:"PUT"
# 418   location:"Tampa-St. Petersburg-Clearwater            FL"  method:"PUT"
# 419          location:"Lake Havasu City-Kingman            AZ"  method:"PUT"
# 420          location:"Lake Havasu City-Kingman            AZ"  method:"PUT"
# 421          location:"Lake Havasu City-Kingman            AZ"  method:"PUT"
# 422   location:"Tampa-St. Petersburg-Clearwater            FL"  method:"PUT"
# 423                               location:null   method:"GET"   page:"Home"
# 424          location:"Lake Havasu City-Kingman            AZ"  method:"PUT"
# 425   location:"Tampa-St. Petersburg-Clearwater            FL"  method:"PUT"
# 426          location:"Lake Havasu City-Kingman            AZ"  method:"PUT"
# 427   location:"Tampa-St. Petersburg-Clearwater            FL"  method:"PUT"
# 428          location:"Lake Havasu City-Kingman            AZ"  method:"PUT"
# 429   location:"Tampa-St. Petersburg-Clearwater            FL"  method:"PUT"
# 430   location:"Tampa-St. Petersburg-Clearwater            FL"  method:"PUT"
# 431          location:"Lake Havasu City-Kingman            AZ"  method:"PUT"
#
#        page:"NextSong"  registration:1540794356796.0  sessionId:992  \
# 0      page:"NextSong"  registration:1540794356796.0  sessionId:992
# 1      page:"NextSong"  registration:1540794356796.0  sessionId:992
# 2      page:"NextSong"  registration:1540794356796.0  sessionId:992
# 3      page:"NextSong"  registration:1540794356796.0  sessionId:992
# 4      page:"NextSong"  registration:1540794356796.0  sessionId:992
# 5    registration:null                 sessionId:952      song:null
# 6    registration:null                 sessionId:952      song:null
# 7          page:"Home"  registration:1541022995796.0  sessionId:952
# 8          page:"Home"  registration:1540794356796.0  sessionId:992
# 9          page:"Home"  registration:1540266185796.0  sessionId:932
# 10   registration:null                 sessionId:964      song:null
# 11         page:"Home"  registration:1540685147796.0  sessionId:964
# 12     page:"NextSong"  registration:1540685147796.0  sessionId:964
# 13     page:"NextSong"  registration:1540685147796.0  sessionId:964
# 14     page:"NextSong"  registration:1540999292796.0  sessionId:801
# 15         page:"Home"  registration:1541081807796.0  sessionId:996
# 16     page:"NextSong"  registration:1541081807796.0  sessionId:996
# 17     page:"NextSong"  registration:1540832693796.0  sessionId:976
# 18     page:"NextSong"  registration:1540832693796.0  sessionId:976
# 19     page:"NextSong"  registration:1540907087796.0  sessionId:887
# 20     page:"NextSong"  registration:1540907087796.0  sessionId:887
# 21     page:"NextSong"  registration:1540872073796.0  sessionId:922
# 22     page:"NextSong"  registration:1540907087796.0  sessionId:887
# 23     page:"NextSong"  registration:1540872073796.0  sessionId:922
# 24       page:"Logout"  registration:1540872073796.0  sessionId:922
# 25   registration:null                 sessionId:922      song:null
# 26   registration:null                 sessionId:922      song:null
# 27         page:"Home"  registration:1540872073796.0  sessionId:922
# 28     page:"NextSong"  registration:1540907087796.0  sessionId:887
# 29     page:"NextSong"  registration:1540872073796.0  sessionId:922
# ..                 ...                           ...            ...
# 402    page:"NextSong"  registration:1540558108796.0  sessionId:954
# 403    page:"NextSong"  registration:1541057188796.0  sessionId:984
# 404    page:"NextSong"  registration:1540558108796.0  sessionId:954
# 405    page:"NextSong"  registration:1540558108796.0  sessionId:954
# 406    page:"NextSong"  registration:1541057188796.0  sessionId:984
# 407        page:"Home"  registration:1541057188796.0  sessionId:984
# 408    page:"NextSong"  registration:1540558108796.0  sessionId:954
# 409    page:"NextSong"  registration:1541057188796.0  sessionId:984
# 410    page:"NextSong"  registration:1540558108796.0  sessionId:954
# 411    page:"NextSong"  registration:1541057188796.0  sessionId:984
# 412    page:"NextSong"  registration:1540558108796.0  sessionId:954
# 413    page:"NextSong"  registration:1541057188796.0  sessionId:984
# 414    page:"NextSong"  registration:1540558108796.0  sessionId:954
# 415    page:"NextSong"  registration:1541057188796.0  sessionId:984
# 416    page:"NextSong"  registration:1540558108796.0  sessionId:954
# 417    page:"NextSong"  registration:1541057188796.0  sessionId:984
# 418    page:"NextSong"  registration:1540558108796.0  sessionId:954
# 419    page:"NextSong"  registration:1541057188796.0  sessionId:984
# 420    page:"NextSong"  registration:1541057188796.0  sessionId:984
# 421    page:"NextSong"  registration:1541057188796.0  sessionId:984
# 422    page:"NextSong"  registration:1540558108796.0  sessionId:954
# 423  registration:null                sessionId:1043      song:null
# 424    page:"NextSong"  registration:1541057188796.0  sessionId:984
# 425    page:"NextSong"  registration:1540558108796.0  sessionId:954
# 426    page:"NextSong"  registration:1541057188796.0  sessionId:984
# 427    page:"NextSong"  registration:1540558108796.0  sessionId:954
# 428    page:"NextSong"  registration:1541057188796.0  sessionId:984
# 429    page:"NextSong"  registration:1540558108796.0  sessionId:954
# 430    page:"NextSong"  registration:1540558108796.0  sessionId:954
# 431    page:"NextSong"  registration:1541057188796.0  sessionId:984
#
#                  song:"Jenny Take A Ride (LP Version)"        status:200  \
# 0                         song:"The TIde (LP Version)"        status:200
# 1                     song:"Two Rights Make One Wrong"        status:200
# 2                            song:"Way Of The Samurai"        status:200
# 3                                    song:"Sexy Bitch"        status:200
# 4                                       song:"Hurtful"        status:200
# 5                                           status:200  ts:1543365211796
# 6                                           status:307  ts:1543365212796
# 7                                            song:null        status:200
# 8                                            song:null        status:200
# 9                                            song:null        status:200
# 10                                          status:307  ts:1543369200796
# 11                                           song:null        status:200
# 12                          song:"Holdin' On Together"        status:200
# 13                                    song:"Mardy Bum"        status:200
# 14                                 song:"Burn For You"        status:200
# 15                                           song:null        status:200
# 16                                   song:"Who's Real"        status:200
# 17               song:"Dog Days Are Over (Radio Edit)"        status:200
# 18                                  song:"Blue Orchid"        status:200
# 19                     song:"You (w\/o Organ Version)"        status:200
# 20                                    song:"Mr. Jones"        status:200
# 21                             song:"A Different City"        status:200
# 22                                song:"Hailie's Song"        status:200
# 23                                   song:"Wild Child"        status:200
# 24                                           song:null        status:307
# 25                                          status:200  ts:1543389661796
# 26                                          status:307  ts:1543389662796
# 27                                           song:null        status:200
# 28                                 song:"La Vida Pasa"        status:200
# 29                                song:"The Interview"        status:200
# ..                                                 ...               ...
# 402  song:"Plastic Beach (Feat. Mick Jones and Paul...        status:200
# 403         song:"Smashed Into Pieces (Album Version)"        status:200
# 404                                  song:"Kickstarts"        status:200
# 405              song:"In My Car (I'll Be The Driver)"        status:200
# 406                                     song:"Ease Up"        status:200
# 407                                          song:null        status:200
# 408                                 song:"Jesus Walks"        status:200
# 409                             song:"I Need A Dollar"        status:200
# 410                                         song:"GO!"        status:200
# 411                                     song:"Iko Iko"        status:200
# 412                                   song:"Mushaboom"        status:200
# 413        song:"The Coolest (Explicit Album Version)"        status:200
# 414                       song:"Stairway To The Stars"        status:200
# 415                              song:"The Bitter End"        status:200
# 416       song:"Making Money Off God feat. Bus Driver"        status:200
# 417                                  song:"The Puzzle"        status:200
# 418             song:"Paradise By The Dashboard Light"        status:200
# 419  song:"It's Not Easy (Being Green) (Featuring P...        status:200
# 420                                         song:"Ego"        status:200
# 421                                song:"Transmission"        status:200
# 422            song:"I Wanna Make You Close Your Eyes"        status:200
# 423                                         status:200  ts:1543448703796
# 424                                  song:"At The Hop"        status:200
# 425                         song:"If Looks Could Kill"        status:200
# 426                                     song:"Breathe"        status:200
# 427                                     song:"Peligro"        status:200
# 428  song:"Mittelfinga ab feat. Sido_ MOK_ B-Tight_...        status:200
# 429                         song:"Never Met The Gooch"        status:200
# 430                                  song:"Amityville"        status:200
# 431                           song:"So Long_ Lonesome"        status:200
#
#      ts:1543363215796  \
# 0    ts:1543363420796
# 1    ts:1543363778796
# 2    ts:1543364349796
# 3    ts:1543364729796
# 4    ts:1543364950796
# 5      userAgent:null
# 6      userAgent:null
# 7    ts:1543365223796
# 8    ts:1543365724796
# 9    ts:1543368722796
# 10     userAgent:null
# 11   ts:1543369248796
# 12   ts:1543369249796
# 13   ts:1543369456796
# 14   ts:1543377306796
# 15   ts:1543381987796
# 16   ts:1543382018796
# 17   ts:1543386015796
# 18   ts:1543386234796
# 19   ts:1543389090796
# 20   ts:1543389321796
# 21   ts:1543389451796
# 22   ts:1543389593796
# 23   ts:1543389650796
# 24   ts:1543389651796
# 25     userAgent:null
# 26     userAgent:null
# 27   ts:1543389697796
# 28   ts:1543389913796
# 29   ts:1543389920796
# ..                ...
# 402  ts:1543446294796
# 403  ts:1543446495796
# 404  ts:1543446521796
# 405  ts:1543446701796
# 406  ts:1543446717796
# 407  ts:1543446858796
# 408  ts:1543446899796
# 409  ts:1543446955796
# 410  ts:1543447095796
# 411  ts:1543447199796
# 412  ts:1543447319796
# 413  ts:1543447377796
# 414  ts:1543447542796
# 415  ts:1543447689796
# 416  ts:1543447730796
# 417  ts:1543447879796
# 418  ts:1543447973796
# 419  ts:1543448083796
# 420  ts:1543448305796
# 421  ts:1543448541796
# 422  ts:1543448570796
# 423    userAgent:null
# 424  ts:1543448795796
# 425  ts:1543448809796
# 426  ts:1543448929796
# 427  ts:1543449016796
# 428  ts:1543449264796
# 429  ts:1543449294796
# 430  ts:1543449413796
# 431  ts:1543449470796
#
#     userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit\/537.36 (KHTML  \
# 0    userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 1    userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 2    userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 3    userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 4    userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 5                                           userId:""}
# 6                                           userId:""}
# 7    userAgent:"Mozilla\/5.0 (Macintosh; Intel Mac ...
# 8    userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 9    userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 10                                          userId:""}
# 11   userAgent:"Mozilla\/5.0 (Macintosh; Intel Mac ...
# 12   userAgent:"Mozilla\/5.0 (Macintosh; Intel Mac ...
# 13   userAgent:"Mozilla\/5.0 (Macintosh; Intel Mac ...
# 14   userAgent:"\"Mozilla\/5.0 (Windows NT 6.1; WOW...
# 15   userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 16   userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 17   userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 18   userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 19   userAgent:"\"Mozilla\/5.0 (Windows NT 6.3; WOW...
# 20   userAgent:"\"Mozilla\/5.0 (Windows NT 6.3; WOW...
# 21   userAgent:"Mozilla\/5.0 (Windows NT 6.1; WOW64...
# 22   userAgent:"\"Mozilla\/5.0 (Windows NT 6.3; WOW...
# 23   userAgent:"Mozilla\/5.0 (Windows NT 6.1; WOW64...
# 24   userAgent:"Mozilla\/5.0 (Windows NT 6.1; WOW64...
# 25                                          userId:""}
# 26                                          userId:""}
# 27   userAgent:"Mozilla\/5.0 (Windows NT 6.1; WOW64...
# 28   userAgent:"\"Mozilla\/5.0 (Windows NT 6.3; WOW...
# 29   userAgent:"Mozilla\/5.0 (Windows NT 6.1; WOW64...
# ..                                                 ...
# 402  userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 403  userAgent:"\"Mozilla\/5.0 (Windows NT 6.1; WOW...
# 404  userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 405  userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 406  userAgent:"\"Mozilla\/5.0 (Windows NT 6.1; WOW...
# 407  userAgent:"\"Mozilla\/5.0 (Windows NT 6.1; WOW...
# 408  userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 409  userAgent:"\"Mozilla\/5.0 (Windows NT 6.1; WOW...
# 410  userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 411  userAgent:"\"Mozilla\/5.0 (Windows NT 6.1; WOW...
# 412  userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 413  userAgent:"\"Mozilla\/5.0 (Windows NT 6.1; WOW...
# 414  userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 415  userAgent:"\"Mozilla\/5.0 (Windows NT 6.1; WOW...
# 416  userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 417  userAgent:"\"Mozilla\/5.0 (Windows NT 6.1; WOW...
# 418  userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 419  userAgent:"\"Mozilla\/5.0 (Windows NT 6.1; WOW...
# 420  userAgent:"\"Mozilla\/5.0 (Windows NT 6.1; WOW...
# 421  userAgent:"\"Mozilla\/5.0 (Windows NT 6.1; WOW...
# 422  userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 423                                         userId:""}
# 424  userAgent:"\"Mozilla\/5.0 (Windows NT 6.1; WOW...
# 425  userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 426  userAgent:"\"Mozilla\/5.0 (Windows NT 6.1; WOW...
# 427  userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 428  userAgent:"\"Mozilla\/5.0 (Windows NT 6.1; WOW...
# 429  userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 430  userAgent:"\"Mozilla\/5.0 (Macintosh; Intel Ma...
# 431  userAgent:"\"Mozilla\/5.0 (Windows NT 6.1; WOW...
#
#      like Gecko) Chrome\/36.0.1985.143 Safari\/537.36\""  userId:"80"}
# 0     like Gecko) Chrome\/36.0.1985.143 Safari\/537...    userId:"80"}
# 1     like Gecko) Chrome\/36.0.1985.143 Safari\/537...    userId:"80"}
# 2     like Gecko) Chrome\/36.0.1985.143 Safari\/537...    userId:"80"}
# 3     like Gecko) Chrome\/36.0.1985.143 Safari\/537...    userId:"80"}
# 4     like Gecko) Chrome\/36.0.1985.143 Safari\/537...    userId:"80"}
# 5                                                  NaN             NaN
# 6                                                  NaN             NaN
# 7                                         userId:"44"}             NaN
# 8     like Gecko) Chrome\/36.0.1985.143 Safari\/537...    userId:"80"}
# 9       like Gecko) Version\/7.0.5 Safari\/537.77.4\""    userId:"10"}
# 10                                                 NaN             NaN
# 11                                        userId:"92"}             NaN
# 12                                        userId:"92"}             NaN
# 13                                        userId:"92"}             NaN
# 14    like Gecko) Chrome\/36.0.1985.143 Safari\/537...    userId:"74"}
# 15      like Gecko) Version\/7.0.6 Safari\/537.78.2\""    userId:"55"}
# 16      like Gecko) Version\/7.0.6 Safari\/537.78.2\""    userId:"55"}
# 17      like Gecko) Version\/7.0.5 Safari\/537.77.4\""    userId:"40"}
# 18      like Gecko) Version\/7.0.5 Safari\/537.77.4\""    userId:"40"}
# 19    like Gecko) Chrome\/36.0.1985.125 Safari\/537...    userId:"58"}
# 20    like Gecko) Chrome\/36.0.1985.125 Safari\/537...    userId:"58"}
# 21                                         userId:"9"}             NaN
# 22    like Gecko) Chrome\/36.0.1985.125 Safari\/537...    userId:"58"}
# 23                                         userId:"9"}             NaN
# 24                                         userId:"9"}             NaN
# 25                                                 NaN             NaN
# 26                                                 NaN             NaN
# 27                                         userId:"9"}             NaN
# 28    like Gecko) Chrome\/36.0.1985.125 Safari\/537...    userId:"58"}
# 29                                         userId:"9"}             NaN
# ..                                                 ...             ...
# 402     like Gecko) Version\/7.0.6 Safari\/537.78.2\""    userId:"73"}
# 403   like Gecko) Chrome\/36.0.1985.125 Safari\/537...    userId:"24"}
# 404     like Gecko) Version\/7.0.6 Safari\/537.78.2\""    userId:"73"}
# 405     like Gecko) Version\/7.0.6 Safari\/537.78.2\""    userId:"73"}
# 406   like Gecko) Chrome\/36.0.1985.125 Safari\/537...    userId:"24"}
# 407   like Gecko) Chrome\/36.0.1985.125 Safari\/537...    userId:"24"}
# 408     like Gecko) Version\/7.0.6 Safari\/537.78.2\""    userId:"73"}
# 409   like Gecko) Chrome\/36.0.1985.125 Safari\/537...    userId:"24"}
# 410     like Gecko) Version\/7.0.6 Safari\/537.78.2\""    userId:"73"}
# 411   like Gecko) Chrome\/36.0.1985.125 Safari\/537...    userId:"24"}
# 412     like Gecko) Version\/7.0.6 Safari\/537.78.2\""    userId:"73"}
# 413   like Gecko) Chrome\/36.0.1985.125 Safari\/537...    userId:"24"}
# 414     like Gecko) Version\/7.0.6 Safari\/537.78.2\""    userId:"73"}
# 415   like Gecko) Chrome\/36.0.1985.125 Safari\/537...    userId:"24"}
# 416     like Gecko) Version\/7.0.6 Safari\/537.78.2\""    userId:"73"}
# 417   like Gecko) Chrome\/36.0.1985.125 Safari\/537...    userId:"24"}
# 418     like Gecko) Version\/7.0.6 Safari\/537.78.2\""    userId:"73"}
# 419   like Gecko) Chrome\/36.0.1985.125 Safari\/537...    userId:"24"}
# 420   like Gecko) Chrome\/36.0.1985.125 Safari\/537...    userId:"24"}
# 421   like Gecko) Chrome\/36.0.1985.125 Safari\/537...    userId:"24"}
# 422     like Gecko) Version\/7.0.6 Safari\/537.78.2\""    userId:"73"}
# 423                                                NaN             NaN
# 424   like Gecko) Chrome\/36.0.1985.125 Safari\/537...    userId:"24"}
# 425     like Gecko) Version\/7.0.6 Safari\/537.78.2\""    userId:"73"}
# 426   like Gecko) Chrome\/36.0.1985.125 Safari\/537...    userId:"24"}
# 427     like Gecko) Version\/7.0.6 Safari\/537.78.2\""    userId:"73"}
# 428   like Gecko) Chrome\/36.0.1985.125 Safari\/537...    userId:"24"}
# 429     like Gecko) Version\/7.0.6 Safari\/537.78.2\""    userId:"73"}
# 430     like Gecko) Version\/7.0.6 Safari\/537.78.2\""    userId:"73"}
# 431   like Gecko) Chrome\/36.0.1985.125 Safari\/537...    userId:"24"}
#
# [432 rows x 20 columns]

# %% [markdown]
# ## Pre-signed URLs
#
# This is another alternative to read private files.
#
# - Expire after a certain timeframe
# - Great for temporary access

# %%
s3.upload_file(
    Filename="cities.csv",
    Key="more_cities.csv",
    Bucket="dned-miguelccarvalho-bucket-demo",
)

# %%
share_url = s3.generate_presigned_url(
    ClientMethod="get_object",
    ExpiresIn=3600,
    Params={
        "Bucket": "dned-miguelccarvalho-bucket-demo", 
        "Key": "more_cities.csv",
    }
)

# %%
share_url
# Out:
# 'https://dned-miguelccarvalho-bucket-demo.s3.amazonaws.com/more_cities.csv?AWSAccessKeyId=AKIARGNCQPRZTWLBQDP3&Signature=sjQTrHm%2FrbhuF3TkHH8jvls1NOg%3D&Expires=1581610349'

# %%
# not working...
pd.read_csv(share_url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-86-4b50afc29978> in <module>
# ----> 1 pd.read_csv(share_url)
#
# ~/.pyenv/versions/3.7.5/envs/myenv/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/.pyenv/versions/3.7.5/envs/myenv/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     411     compression = _infer_compression(filepath_or_buffer, compression)
#     412     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(
# --> 413         filepath_or_buffer, encoding, compression)
#     414     kwds['compression'] = compression
#     415
#
# ~/.pyenv/versions/3.7.5/envs/myenv/lib/python3.7/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#     200
#     201     if _is_url(filepath_or_buffer):
# --> 202         req = _urlopen(filepath_or_buffer)
#     203         content_encoding = req.headers.get('Content-Encoding', None)
#     204         if content_encoding == 'gzip':
#
# ~/.pyenv/versions/3.7.5/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/.pyenv/versions/3.7.5/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/.pyenv/versions/3.7.5/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~/.pyenv/versions/3.7.5/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~/.pyenv/versions/3.7.5/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/.pyenv/versions/3.7.5/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 400: Bad Request

# %% [markdown]
# ### Load multiple files into on DataFrame

# %%
# create a list to  hold our dfs
df_list = []

# request the list of csv's from S3 with prefix
response = s3.list_objects(
    Bucket="dned-miguelccarvalho-bucket-demo",
    Prefix="cit",
)

# get response contents
request_files = response["Contents"]

# %%
import ipdb
for file in request_files:
#     ipdb.set_trace()
    try:
        obj = s3.get_object(Bucket="gid-requests", Key=file["Key"])
    except s3.exceptions.ClientError:
        continue
    obj_df = pd.read_csv(obj["Body"])
    
    df_list.append(obj_df)

# %%
# if we had anything
pd.concat(df_list, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-daf123b446e9> in <module>
#       1 # if we had anything
# ----> 2 pd.concat(df_list, ignore_index=True)
#
# ~/.pyenv/versions/3.7.5/envs/myenv/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     226                        keys=keys, levels=levels, names=names,
#     227                        verify_integrity=verify_integrity,
# --> 228                        copy=copy, sort=sort)
#     229     return op.get_result()
#     230
#
# ~/.pyenv/versions/3.7.5/envs/myenv/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     260
#     261         if len(objs) == 0:
# --> 262             raise ValueError('No objects to concatenate')
#     263
#     264         if keys is None:
#
# ValueError: No objects to concatenate

# %% [markdown]
# ## Sharing Files through a Website
#
# S3 is able to serve as HTML pages which is useful for sharing the results of analysis with stakeholders.
#
# ### `to_html`
#
# pandas has a `to_html` method which we can use to write a pandas dataframe to html file.
#
# Useful optional parameters are:
# - `render_links`
#     - make URLs clickable
# - `columns`
#     - only show these cols
# - `border`
#     - make border thicker of thinner

# %% [markdown]
# ### Uploading an HTML file

# %%
pd.read_csv("cities.csv").to_html("cities.html")

# %%
s3.upload_file(
    Filename="cities.html",
    Bucket="dned-miguelccarvalho-bucket-demo",
    Key="cities.html",
    ExtraArgs={
        "ContentType": "text/html", # this tells browser how to render file
        "ACL": "public-read",
    }
)

# %% [markdown]
# https://dned-miguelccarvalho-bucket-demo.s3.eu-west-2.amazonaws.com/cities.html

# %% [markdown]
# ### Showing an index table for the files we want to share

# %%
r = s3.list_objects(
    Bucket="dned-miguelccarvalho-bucket-demo",
    Prefix="cit",
)

# %%
objects_df = pd.DataFrame(r["Contents"])

# %%
objects_df
# Out:
#                                  ETag           Key              LastModified  \
# 0  "2dd39cb6de5ecc471fa37f1f2aac759f"    cities.csv 2020-02-13 14:28:38+00:00
# 1  "0b8ccf426c22318acd950ab95b084f73"   cities.html 2020-02-13 15:31:55+00:00
# 2  "2dd39cb6de5ecc471fa37f1f2aac759f"  cities_2.csv 2020-02-13 14:29:26+00:00
#
#                                                Owner   Size StorageClass
# 0  {'ID': 'e6119f625207062af5bb798a6418c2872efd1a...   8402     STANDARD
# 1  {'ID': 'e6119f625207062af5bb798a6418c2872efd1a...  29530     STANDARD
# 2  {'ID': 'e6119f625207062af5bb798a6418c2872efd1a...   8402     STANDARD

# %%
# add a link to each file
base_url = "https://dned-miguelccarvalho-bucket-demo.s3.eu-west-2.amazonaws.com/"
objects_df["Link"] = base_url + objects_df["Key"]

# %%
objects_df.to_html(
    "html_listing.html",
    columns=["Link", "LastModified", "Size"],
    render_links=True,
)

# %%
s3.upload_file(
    Filename="html_listing.html",
    Bucket="dned-miguelccarvalho-bucket-demo",
    Key="html_listing.html",
    ExtraArgs={
        "ContentType": "text/html", # this tells browser how to render file
        "ACL": "public-read",
    }
)

# %% [markdown]
# https://dned-miguelccarvalho-bucket-demo.s3.eu-west-2.amazonaws.com/html_listing.html

# %% [markdown]
# # SNS Topics

# %% [markdown]
# SNS is used to send emails, notifications, sms to clients.
#
# The framework is that there are:
# - Publishers
#     - those sending content
# - Subscribers
#     - those consuming content
#
# Publishers send content to *topics* which subscribers subscribe to.

# %% [markdown]
# ### About topics
#
# Every topic has an **ARN** (Amazon Resource Name) which is the unique ID to the topic. The subscriptions to the topics have a unique ID as well.

# %%
# creeating a topic with boto
sns = boto3.client(
    "sns",
    region_name="eu-west-1"
    # we can omit the other params since awscli did that for us
)

# %%
# this operation is idempotent; grab the ARN
response = sns.create_topic(Name="city_alerts")
response["TopicArn"]

# better in a one-liner
response = sns.create_topic(Name="city_alerts")["TopicArn"]

# %%
response
# Out:
# 'arn:aws:sns:eu-west-1:082482068595:city_alerts'

# %% [markdown]
# ### List topics

# %%
sns.list_topics()
# Out:
# {'Topics': [{'TopicArn': 'arn:aws:sns:eu-west-1:082482068595:city_alerts'}], 'ResponseMetadata': {'RequestId': 'ea692f5e-d167-525d-978f-79e1ab9368c0', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'ea692f5e-d167-525d-978f-79e1ab9368c0', 'content-type': 'text/xml', 'content-length': '376', 'date': 'Thu, 13 Feb 2020 16:26:28 GMT'}, 'RetryAttempts': 0}}

# %%
topic_arn = 'arn:aws:sns:eu-west-1:082482068595:city_alerts'

# %% [markdown]
# ### Deleting a topic

# %%
sns.delete_topic(TopicArn=response["TopicArn"])
# Out:
# {'ResponseMetadata': {'RequestId': '33584505-4a2d-52bc-b215-13ba3102c8f9', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '33584505-4a2d-52bc-b215-13ba3102c8f9', 'content-type': 'text/xml', 'content-length': '201', 'date': 'Thu, 13 Feb 2020 16:27:26 GMT'}, 'RetryAttempts': 0}}

# %% [markdown]
# ## SNS Subscriptions
#
# Every subscription to a topic has:
# - unique ID
# - protocol
#     - there are several protocols, we'll only see EMAIL and SMS
# - status
#     - confirmed or  pending  confirmation; phone numbers are  automatically confirmed but emails  must be confirmed through a confirmation email in the inbox
# - endpoint
#     - the specific phone number or email the message should be sent to

# %% [markdown]
# ### Creating an SMS subscription

# %%
sns.subscribe(
    TopicArn=response,
    Protocol="SMS",
    Endpoint="+447492937145"
)
# Out:
# {'SubscriptionArn': 'arn:aws:sns:eu-west-1:082482068595:city_alerts:a8edde6d-8d47-4c41-bb24-56bae6960cd6',
#  'ResponseMetadata': {'RequestId': '66a5e87d-01ad-5185-beac-bec27d557e09',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '66a5e87d-01ad-5185-beac-bec27d557e09',
#    'content-type': 'text/xml',
#    'content-length': '361',
#    'date': 'Thu, 13 Feb 2020 16:35:04 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ### Creating an email subscription

# %%
sns.subscribe(
    TopicArn=response,
    Protocol="EMAIL",
    Endpoint="miguelcansadocarvalho@gmail.com"
)
# Out:
# {'SubscriptionArn': 'pending confirmation',
#  'ResponseMetadata': {'RequestId': 'd278d728-bc5f-5824-b801-8197c1174daf',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'd278d728-bc5f-5824-b801-8197c1174daf',
#    'content-type': 'text/xml',
#    'content-length': '298',
#    'date': 'Thu, 13 Feb 2020 16:36:24 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ### Listing subscriptions

# %%
sns.list_subscriptions_by_topic(
    TopicArn=response,
)
# Out:
# {'Subscriptions': [{'SubscriptionArn': 'arn:aws:sns:eu-west-1:082482068595:city_alerts:b1b1af98-68b4-4cd1-97f9-9015c41081ad',
#    'Owner': '082482068595',
#    'Protocol': 'email',
#    'Endpoint': 'miguelcansadocarvalho@gmail.com',
#    'TopicArn': 'arn:aws:sns:eu-west-1:082482068595:city_alerts'},
#   {'SubscriptionArn': 'arn:aws:sns:eu-west-1:082482068595:city_alerts:a8edde6d-8d47-4c41-bb24-56bae6960cd6',
#    'Owner': '082482068595',
#    'Protocol': 'sms',
#    'Endpoint': '+447492937145',
#    'TopicArn': 'arn:aws:sns:eu-west-1:082482068595:city_alerts'}],
#  'ResponseMetadata': {'RequestId': '1f895936-80e4-5a5a-ae60-0f89fd9ba81d',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '1f895936-80e4-5a5a-ae60-0f89fd9ba81d',
#    'content-type': 'text/xml',
#    'content-length': '1051',
#    'date': 'Thu, 13 Feb 2020 16:37:19 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ### Listing all subscriptions

# %%
sns.list_subscriptions()["Subscriptions"]
# Out:
# []

# %% [markdown]
# ### Delete subscription

# %%
sns.unsubscribe(SubscriptionArn='arn:aws:sns:eu-west-1:082482068595:city_alerts:b1b1af98-68b4-4cd1-97f9-9015c41081ad')
# Out:
# {'ResponseMetadata': {'RequestId': '3d3c51bf-5888-5da8-9a90-0700268e496f',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '3d3c51bf-5888-5da8-9a90-0700268e496f',
#    'content-type': 'text/xml',
#    'content-length': '201',
#    'date': 'Thu, 13 Feb 2020 16:39:34 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ## Sending Messages

# %% [markdown]
# ### Publishing to a Topic
#
# When we publish to a topic, all our subscribers will receive it.

# %%
response = sns.publish(
    TopicArn=topic_arn,
    Message="Body of text or email",
    Subject="Subject Line for Email",
)

# %% [markdown]
# ### Sending a one-off SMS

# %%
response = sns.publish(
    PhoneNumber="+447492937145",
    Message="Fran é um purdle",
)

# %% [markdown]
# # Pattern Rekognition

# %% [markdown]
# This is a computer vision API by AWS which:
# - detects objects in images
# - extracts text from images

# %% [markdown]
# ## Learning new AWS services
#
# 1. Find them on the AWS interface
# 2. Look them up on [boto docs](https://boto3.amazonaws.com/v1/documentation/api/latest/index.html)
# 3. Find the parameter to pass to create client as well as methods

# %% [markdown]
# ## Uploading a test image to S3

# %%
s3 = boto3.client("s3", region_name="us-east-1")

# %%
s3.create_bucket(Bucket="images-datacamp-test-miguel")
# Out:
# {'ResponseMetadata': {'RequestId': '998925FA24F874A2',
#   'HostId': 'Jd7Cbfugb0BWgw1lOGmA4lvttj28LHifmfM4PBmyjXVSsRWACYPgvVag0vnga09yqfcB1bEBV3Q=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'Jd7Cbfugb0BWgw1lOGmA4lvttj28LHifmfM4PBmyjXVSsRWACYPgvVag0vnga09yqfcB1bEBV3Q=',
#    'x-amz-request-id': '998925FA24F874A2',
#    'date': 'Thu, 13 Feb 2020 17:26:42 GMT',
#    'location': '/images-datacamp-test-miguel',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Location': '/images-datacamp-test-miguel'}

# %%
s3.upload_file(
    Filename="kitchen.png",
    Bucket="images-datacamp-test-miguel",
    Key="kitchen.png",
    ExtraArgs={
        "ACL": "public-read",
    }
)

# %% [markdown]
# ## Analyzing the image

# %%
import boto3

# make sure boto3 rekognition client is in the same region
# as the image! 
rekog = boto3.client(
    "rekognition",
    region_name="us-east-1",
)

# %%
response = rekog.detect_labels(
    Image={
        'S3Object': {
            'Bucket': 'images-datacamp-test-miguel',
            'Name': 'kitchen.png',
        }
    },
    MaxLabels=10,
)

# %%
response
# Out:
# {'Labels': [{'Name': 'Laundry',
#    'Confidence': 95.0337905883789,
#    'Instances': [],
#    'Parents': []},
#   {'Name': 'Housing',
#    'Confidence': 91.11283874511719,
#    'Instances': [],
#    'Parents': [{'Name': 'Building'}]},
#   {'Name': 'Building',
#    'Confidence': 91.11283874511719,
#    'Instances': [],
#    'Parents': []},
#   {'Name': 'Washer',
#    'Confidence': 85.34657287597656,
#    'Instances': [],
#    'Parents': [{'Name': 'Appliance'}]},
#   {'Name': 'Appliance',
#    'Confidence': 85.34657287597656,
#    'Instances': [],
#    'Parents': []},
#   {'Name': 'Window',
#    'Confidence': 73.19082641601562,
#    'Instances': [],
#    'Parents': []},
#   {'Name': 'Interior Design',
#    'Confidence': 70.55426025390625,
#    'Instances': [],
#    'Parents': [{'Name': 'Indoors'}]},
#   {'Name': 'Indoors',
#    'Confidence': 70.55426025390625,
#    'Instances': [],
#    'Parents': []},
#   {'Name': 'Architecture',
#    'Confidence': 62.6004753112793,
#    'Instances': [],
#    'Parents': [{'Name': 'Building'}]},
#   {'Name': 'Sink Faucet',
#    'Confidence': 61.65392303466797,
#    'Instances': [{'BoundingBox': {'Width': 0.18311728537082672,
#       'Height': 0.20555688440799713,
#       'Left': 0.6535103917121887,
#       'Top': 0.4096108078956604},
#      'Confidence': 61.65392303466797}],
#    'Parents': []}],
#  'LabelModelVersion': '2.0',
#  'ResponseMetadata': {'RequestId': 'fdefffc5-6ade-46ce-87c8-03b8cb394d85',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1',
#    'date': 'Thu, 13 Feb 2020 17:31:50 GMT',
#    'x-amzn-requestid': 'fdefffc5-6ade-46ce-87c8-03b8cb394d85',
#    'content-length': '1066',
#    'connection': 'keep-alive'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ## Comprehending Text
#
# AWS provides two main services for making sense of text:
# - Comprehend
# - Translate
#
# ### Translate

# %%
translate = boto3.client("translate", region_name="us-east-1")

# %%
response = translate.translate_text(
    Text="Olá, tudo bem?",
    SourceLanguageCode="auto",
    TargetLanguageCode="en",
)

# %%
response
# Out:
# {'TranslatedText': 'Hey, you all right?',
#  'SourceLanguageCode': 'pt',
#  'TargetLanguageCode': 'en',
#  'ResponseMetadata': {'RequestId': 'e2280388-c2da-4d52-ac83-8e9742437bc2',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'e2280388-c2da-4d52-ac83-8e9742437bc2',
#    'cache-control': 'no-cache',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '92',
#    'date': 'Thu, 13 Feb 2020 17:43:41 GMT'},
#   'RetryAttempts': 0}}

# %%
# or to go straight to the response
response["TranslatedText"]
# Out:
# 'Hey, you all right?'

# %% [markdown]
# ### Detecting Language

# %%
comprehend = boto3.client("comprehend", region_name="us-east-1")

# %%
response = comprehend.detect_dominant_language(Text="Merhaba, nasilsin?")

# %%
response
# Out:
# {'Languages': [{'LanguageCode': 'tr', 'Score': 0.9938409328460693}],
#  'ResponseMetadata': {'RequestId': 'cc6b7dd3-b23e-4339-936e-56c4211265bd',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'cc6b7dd3-b23e-4339-936e-56c4211265bd',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '64',
#    'date': 'Thu, 13 Feb 2020 17:45:24 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ### Understanding Sentiment

# %%
comprehend.detect_sentiment(
    Text="Não tenho paciência para isto",
    LanguageCode="pt",
)
# Out:
# {'Sentiment': 'NEGATIVE',
#  'SentimentScore': {'Positive': 0.009575205855071545,
#   'Negative': 0.9445379972457886,
#   'Neutral': 0.045885879546403885,
#   'Mixed': 9.258811246581899e-07},
#  'ResponseMetadata': {'RequestId': '8a12b97a-6af3-4d91-8c30-580e0461f590',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '8a12b97a-6af3-4d91-8c30-580e0461f590',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '165',
#    'date': 'Thu, 13 Feb 2020 17:46:30 GMT'},
#   'RetryAttempts': 0}}
